# %%
import pandas as pd
import sklearn
import pickle as pk
from nltk.tokenize import TreebankWordTokenizer

# %%
#shamim imports
import os
import time
import itertools
import numpy as np
import sklearn
import nltk
import pandas as pd
import sys
import codecs
from nltk.classify import NaiveBayesClassifier, DecisionTreeClassifier
from nltk.corpus import stopwords
#from nltk.sentiment import SentimentAnalyzer
#import string 
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neural_network import MLPClassifier
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.externals import joblib
from scipy import interp
import matplotlib.pyplot as plt
from sklearn.metrics import roc_curve, auc

# %% [markdown]
# # importing data

# %%
data = []
with open("../train.ft.txt","r") as f:
    for i in f:
        data.append(i)

# %%
train_data = data[:20000]

# %% [markdown]
# # Tokenizing data and extracting labels

# %%
tk = TreebankWordTokenizer()
labels = []
for i in range(len(train_data)):
    train_data[i] = tk.tokenize(train_data[i])
    labels.append(train_data[i][0])

# %%
for i in range(len(labels)):
    labels[i] = labels[i].replace("__label__","")

# %% [markdown]
# # Preprocesing

# %%
stop_words = stopwords.words('english')

def remove_punctuation(words): #remove punctuation and convert to lower letters
    return [word for word in words if word.isalpha()]

def remove_stop_words(words):
    return [w for w in words if not w.lower() in stop_words]

# %%
for i in range(len(train_data)):
    train_data[i] = remove_punctuation(train_data[i])
    train_data[i] = remove_stop_words(train_data[i])

# %%
train_data[3]
# Out:
# ['Excellent',
#  'Soundtrack',
#  'truly',
#  'like',
#  'soundtrack',
#  'enjoy',
#  'video',
#  'game',
#  'played',
#  'game',
#  'music',
#  'enjoy',
#  'truly',
#  'relaxing',
#  'disk',
#  'favorites',
#  'Scars',
#  'Time',
#  'Life',
#  'Death',
#  'Forest',
#  'Illusion',
#  'Fortress',
#  'Ancient',
#  'Dragons',
#  'Lost',
#  'Fragment',
#  'Drowned',
#  'Two',
#  'Draggons',
#  'Galdorb',
#  'Home',
#  'Chronomantique',
#  'Prisoners',
#  'Fate',
#  'Gale',
#  'girlfriend',
#  'likes',
#  'ZelbessDisk',
#  'Three',
#  'best',
#  'Garden',
#  'God',
#  'Chronopolis',
#  'Fates',
#  'Jellyfish',
#  'sea',
#  'Burning',
#  'Orphange',
#  'Dragon',
#  'Prayer',
#  'Tower',
#  'Stars',
#  'Dragon',
#  'God',
#  'Radical',
#  'Dreamers',
#  'Unstealable',
#  'excellent',
#  'soundtrack',
#  'brought',
#  'like',
#  'video',
#  'game',
#  'Cross']

# %%
def words_to_str(content,labels):
    pos = []
    neg = []
    for i in range(len(content)):
        ones = ''
        twos = ''
        for j in range(len(content[i])):
            if labels[i] == '1':
                ones += content[i][j] + ' '
            else :
                twos += content[i][j] + ' '
        neg.append(ones)
        pos.append(twos)
    return neg , pos

# %%
negs , pos = words_to_str(train_data , labels)

# %%
def remove_space(a):
    s = ''
    b = []
    for i in a:
        if (i!=''):
            s += i
            b.append(i)
    return s,b

# %%
negs_s,negs = remove_space(negs)
pos_s,pos = remove_space(pos)

# %%
negs
# Out:
# ['Buyer beware book want know read paragraphs star reviews must written Haddon family friends perhaps ca imagine anyone reading whole thing spent evening book friend hysterics reading bits pieces one definitely bad enough entered kind worst book ca believe Amazon even sells kind Maybe offer grade term paper Kill Mockingbird book quite sure Haddon never heard Anyway unless mood send book someone joke far far away one ',
#  'recommend former Alaskan want repeatedly attempting Allman recipes throw cups flour miscellaneous ingredients nearly every time comparing Ed Wood recipes work flawlessly Lisa Rayner excellent Wild Bread sourdough artisan breads kitchen ca help notice recipes work Allman novice thing worked reliably pancakes recipe found places looking reliable recipes concise information starting sourdough maintaining recommend Ed Wood books even old Lisa Rayner written fabulous tome Wild pass historical vignettes interesting enough warrant cost Check library must ',
#  'Maybe got bad experience got FM DVD player rattled pretty loudly sometimes always put tried picture quality great screen got horizontal line thru middle short time would go Plus one reviewers dead remote layout makes sense poor human engineering brought back store saw model Emerson name WM hesitant buy ',
#  'TERRIBLE BUY bought wife birthday toreturn DVD palyer would returned got repalcement DVD player failed work piece junk ',
#  'BEWARE TV set capable recall want flash back channels TV going give remote control comes TV recall function bought Sony universal much better remote recall button However soon learned TV set factory capability may big deal user found annoying ',
#  'Disappointed Romanian book opinion biased takes angle Europe clean proper fails shed light rest understand tourist guides would anyone want tour country forgotten However disappointed Romanian book would never use seen travel guides outlining Europe exclude Romania precision detail DK series left yet disappointment ',
#  'best bought lonely planet used lonely planet book full pictures give info Also ended buying indiv city guide well one scratches surface ',
#  'Either Depends look Either Depends look Star sent feet OD copper Star wo accept returns stars figure actually worth since wo take return figure sell make deal ',
#  'Disappointing text ever think plates markedly inferior previous known ahead time would purchased volume ',
#  'poor screen arrived cardboard box pretty beat screen lightweight cheesy finish worn across entire top knew solid brass expected something least looked decent distance price paid ',
#  'Scraped across whole Purchased screen last week came noticeable scrapes across box came gigantic plenty packaging material screen packaged loosely However since another smaller box thinking scraping begin Still deciding whether go trouble exchanging since another reviewer said would want risk getting another damage really need screen right damage nice screen ',
#  'live ordered shoes replace previous pair ripped apart Clark said make shoe anymore order Sadly second pair ripped place within son since bought similar pair Sperry seem holding much better ',
#  'Profound Truly horrible narrative style work famous founders biographer John Morse arrogant flippant frequently carries tone amateur Yankee historian high passing judgment Southern statesman neither Boston Harvard Perhaps considered penetrating day really represents nothing opinion research thin one must conclude Morse wrote entire manuscript essentially memory little reference primary secondary sources expect historians fact Morse wrote piece years ago rated one star ',
#  'expected daughter loved years old took hours complete Absolutely challenge little essentially clicking screen make play scenes games play nothing figure nothing Save money ',
#  'barbie rapunzel crying child old daughter currently sobbing bedroom result rotten spent hour game painting pretty pictures coloring halfway game program hung would let us leave room click anywhere even exit game start back frozen one spot Barbie disembodied voice urges us explore somewhere else Standard software troubleshooting rebooting Vivendi Games support site currently left weeping frustrating child understand fault game wo hoping incompetent software programming could catch bug old caught first time maybe care problems long get want crying little girl avoid game ',
#  'good ok rental game pretty exciting nice really creative one bad thing one castle kids decorate done whole castle basically either create new username get another game like sister finished castle hours never even looked game nice game fun really worth much money ',
#  'OS X MAC CLASSIC NEGATIVE game work OS X requires CD ca multiple slow tell daughter thinking lot access CD everytime new ca view openning sequence without throwing saved game tasks controls hard user friendly even CRASHES jumpy hard tasks easy possible use grand three year enough patience survive multiple trials get work ',
#  'Bad Deal ordered DVD received substitute never received DVD ordered Importcds Vendor contacted recieve ca rate DVD never bother send back would cost orginally paid future watch name person persons buying thought good understand simple mistake get response good businees spend hundreds dollars month building DVD guess careful future ',
#   'mind',
#   'well',
#   'would',
#   'recomend',
#   'even',
#   'people',
#   'hate',
#   'game',
#   'music',
#   'played',
#   'game',
#   'Chrono',
#   'Cross',
#   'games',
#   'ever',
#   'played',
#   'best',
#   'music',
#   'backs',
#   'away',
#   'crude',
#   'keyboarding',
#   'takes',
#   'fresher',
#   'step',
#   'grate',
#   'guitars',
#   'soulful',
#   'would',
#   'impress',
#   'anyone',
#   'cares',
#   'listen'],
#  ['best',
#   'soundtrack',
#   'ever',
#   'reading',
#   'lot',
#   'reviews',
#   'saying',
#   'best',
#   'soundtrack',
#   'figured',
#   'write',
#   'review',
#   'disagree',
#   'opinino',
#   'Yasunori',
#   'Mitsuda',
#   'ultimate',
#   'music',
#   'timeless',
#   'listening',
#   'years',
#   'beauty',
#   'simply',
#   'refuses',
#   'price',
#   'tag',
#   'pretty',
#   'staggering',
#   'must',
#   'say',
#   'going',
#   'buy',
#   'cd',
#   'much',
#   'money',
#   'one',
#   'feel',
#   'would',
#   'worth',
#   'every',
#   'penny'],
#  ['Amazing',
#   'soundtrack',
#   'favorite',
#   'music',
#   'time',
#   'hands',
#   'intense',
#   'sadness',
#   'Prisoners',
#   'Fate',
#   'means',
#   'played',
#   'game',
#   'hope',
#   'Distant',
#   'Promise',
#   'Girl',
#   'Stole',
#   'Star',
#   'important',
#   'inspiration',
#   'personally',
#   'throughout',
#   'teen',
#   'higher',
#   'energy',
#   'tracks',
#   'like',
#   'Chrono',
#   'Cross',
#   'Time',
#   'Time',
#   'Dreamwatch',
#   'Chronomantique',
#   'indefinably',
#   'remeniscent',
#   'Chrono',
#   'Trigger',
#   'absolutely',
#   'superb',
#   'soundtrack',
#   'amazing',
#   'music',
#   'probably',
#   'best',
#   'composer',
#   'work',
#   'heard',
#   'Xenogears',
#   'soundtrack',
#   'ca',
#   'say',
#   'sure',
#   'even',
#   'never',
#   'played',
#   'game',
#   'would',
#   'worth',
#   'twice',
#   'price',
#   'buy',
#   'wish',
#   'could',
#   'give',
#   'stars'],
#  ['Excellent',
#   'Soundtrack',
#   'truly',
#   'like',
#   'soundtrack',
#   'enjoy',
#   'video',
#   'game',
#   'played',
#   'game',
#   'music',
#   'enjoy',
#   'truly',
#   'relaxing',
#   'disk',
#   'favorites',
#   'Scars',
#   'Time',
#   'Life',
#   'Death',
#   'Forest',
#   'Illusion',
#   'Fortress',
#   'Ancient',
#   'Dragons',
#   'Lost',
#   'Fragment',
#   'Drowned',
#   'Two',
#   'Draggons',
#   'Galdorb',
#   'Home',
#   'Chronomantique',
#   'Prisoners',
#   'Fate',
#   'Gale',
#   'girlfriend',
#   'likes',
#   'ZelbessDisk',
#   'Three',
#   'best',
#   'Garden',
#   'God',
#   'Chronopolis',
#   'Fates',
#   'Jellyfish',
#   'sea',
#   'Burning',
#   'Orphange',
#   'Dragon',
#   'Prayer',
#   'Tower',
#   'Stars',
#   'Dragon',
#   'God',
#   'Radical',
#   'Dreamers',
#   'Unstealable',
#   'excellent',
#   'soundtrack',
#   'brought',
#   'like',
#   'video',
#   'game',
#   'Cross'],
#  ['Remember',
#   'Pull',
#   'Jaw',
#   'Floor',
#   'Hearing',
#   'played',
#   'game',
#   'know',
#   'divine',
#   'music',
#   'Every',
#   'single',
#   'song',
#   'tells',
#   'story',
#   'game',
#   'good',
#   'greatest',
#   'songs',
#   'without',
#   'doubt',
#   'Chrono',
#   'Cross',
#   'Time',
#   'Scar',
#   'Magical',
#   'Dreamers',
#   'Wind',
#   'Stars',
#   'Sea',
#   'Radical',
#   'Dreamers',
#   'Unstolen',
#   'Translation',
#   'varies',
#   'music',
#   'perfect',
#   'ask',
#   'best',
#   'Yasunori',
#   'Mitsuda',
#   'poured',
#   'heart',
#   'wrote',
#   'paper'],
#  ['absolute',
#   'masterpiece',
#   'quite',
#   'sure',
#   'actually',
#   'taking',
#   'time',
#   'read',
#   'played',
#   'game',
#   'least',
#   'heard',
#   'least',
#   'tracks',
#   'whether',
#   'aware',
#   'Mitsuda',
#   'music',
#   'contributed',
#   'greatly',
#   'mood',
#   'every',
#   'single',
#   'minute',
#   'whole',
#   'CDs',
#   'quite',
#   'songs',
#   'exact',
#   'count',
#   'impressively',
#   'remarkable',
#   'soundtrack',
#   'one',
#   'assure',
#   'everything',
#   'every',
#   'listener',
#   'energetic',
#   'Dancing',
#   'Tokage',
#   'Termina',
#   'Home',
#   'slower',
#   'haunting',
#   'Dragon',
#   'God',
#   'purely',
#   'beautifully',
#   'composed',
#   'Time',
#   'Scar',
#   'even',
#   'fantastic',
#   'vocals',
#   'Radical',
#   'Dreamers',
#   'one',
#   'best',
#   'videogame',
#   'soundtracks',
#   'surely',
#   'Mitsuda',
#   'best'],
#  ['Buyer',
#   'beware',
#   'book',
#   'want',
#   'know',
#   'read',
#   'paragraphs',
#   'star',
#   'reviews',
#   'must',
#   'written',
#   'Haddon',
#   'family',
#   'friends',
#   'perhaps',
#   'ca',
#   'imagine',
#   'anyone',
#   'reading',
#   'whole',
#   'thing',
#   'spent',
#   'evening',
#   'book',
#   'friend',
#   'hysterics',
#   'reading',
#   'bits',
#   'pieces',
#   'one',
#   'definitely',
#   'bad',
#   'enough',
#   'entered',
#   'kind',
#   'worst',
#   'book',
#   'ca',
#   'believe',
#   'Amazon',
#   'even',
#   'sells',
#   'kind',
#   'Maybe',
#   'offer',
#   'grade',
#   'term',
#   'paper',
#   'Kill',
#   'Mockingbird',
#   'book',
#   'quite',
#   'sure',
#   'Haddon',
#   'never',
#   'heard',
#   'Anyway',
#   'unless',
#   'mood',
#   'send',
#   'book',
#   'someone',
#   'joke',
#   'far',
#   'far',
#   'away',
#   'one'],
#  ['Glorious',
#   'story',
#   'loved',
#   'Whisper',
#   'wicked',
#   'story',
#   'amazing',
#   'pleasantly',
#   'surprised',
#   'changes',
#   'normaly',
#   'someone',
#   'romance',
#   'novels',
#   'world',
#   'raving',
#   'book',
#   'bought',
#   'loved',
#   'brilliant',
#   'story',
#   'book',
#   'wonderful',
#   'told',
#   'friends',
#   'read',
#   'typical',
#   'romance',
#   'much',
#   'reading',
#   'book',
#   'crime',
#   'becuase',
#   'missing',
#   'heart',
#   'warming',
#   'story'],
#  ['FIVE',
#   'STAR',
#   'BOOK',
#   'finished',
#   'reading',
#   'Whisper',
#   'Wicked',
#   'fell',
#   'love',
#   'expected',
#   'average',
#   'romance',
#   'read',
#   'instead',
#   'found',
#   'one',
#   'favorite',
#   'books',
#   'thought',
#   'could',
#   'predict',
#   'outcome',
#   'shocked',
#   'writting',
#   'descriptive',
#   'heart',
#   'broke',
#   'Julia',
#   'felt',
#   'instead',
#   'distant',
#   'lover',
#   'romance',
#   'novels',
#   'must',
#   'let',
#   'cover',
#   'fool',
#   'book',
#   'spectacular'],
#  ['Whispers',
#   'Wicked',
#   'Saints',
#   'easy',
#   'read',
#   'book',
#   'made',
#   'want',
#   'keep',
#   'reading',
#   'easy',
#   'put',
#   'left',
#   'wanting',
#   'read',
#   'follow',
#   'hope',
#   'coming',
#   'used',
#   'read',
#   'lot',
#   'gotten',
#   'away',
#   'book',
#   'made',
#   'want',
#   'read',
#   'enjoyable'],
#  ['Worst',
#   'complete',
#   'waste',
#   'Typographical',
#   'errors',
#   'poor',
#   'grammar',
#   'totally',
#   'pathetic',
#   'plot',
#   'add',
#   'absolutely',
#   'embarrassed',
#   'author',
#   'disappointed',
#   'actually',
#   'paid',
#   'book'],
#  ['Great',
#   'book',
#   'great',
#   'book',
#   'could',
#   'put',
#   'could',
#   'read',
#   'fast',
#   'Boy',
#   'book',
#   'twist',
#   'turns',
#   'keeps',
#   'guessing',
#   'wanting',
#   'know',
#   'going',
#   'happen',
#   'book',
#   'makes',
#   'fall',
#   'love',
#   'heat',
#   'also',
#   'make',
#   'book',
#   'make',
#   'go',
#   'throu',
#   'several',
#   'quick',
#   'read',
#   'something',
#   'want',
#   'end',
#   'day',
#   'read',
#   'night'],
#  ['Great',
#   'Read',
#   'thought',
#   'book',
#   'brilliant',
#   'yet',
#   'showed',
#   'error',
#   'loved',
#   'fact',
#   'writer',
#   'showed',
#   'loving',
#   'side',
#   'God',
#   'revengeful',
#   'side',
#   'loved',
#   'twisted',
#   'turned',
#   'could',
#   'put',
#   'also',
#   'loved',
#   'glass',
#   'castle'],
#  ['Oh',
#   'please',
#   'guess',
#   'romance',
#   'novel',
#   'lover',
#   'one',
#   'discerning',
#   'others',
#   'beware',
#   'absolute',
#   'figured',
#   'trouble',
#   'typo',
#   'prominently',
#   'featured',
#   'back',
#   'cover',
#   'first',
#   'page',
#   'book',
#   'removed',
#   'Wait',
#   'maybe',
#   'missing',
#   'quick',
#   'beginning',
#   'makes',
#   'intentional',
#   'churning',
#   'prose',
#   'satiric',
#   'Phew',
#   'glad',
#   'waste'],
#  ['Awful',
#   'beyond',
#   'belief',
#   'feel',
#   'write',
#   'keep',
#   'others',
#   'wasting',
#   'book',
#   'seems',
#   'written',
#   'grader',
#   'poor',
#   'grammatical',
#   'skills',
#   'age',
#   'another',
#   'reviewer',
#   'points',
#   'misspelling',
#   'cover',
#   'believe',
#   'least',
#   'one',
#   'per',
#   'example',
#   'mentioned',
#   'twice',
#   'lean',
#   'distracted',
#   'poor',
#   'writing',
#   'weak',
#   'plot',
#   'decided',
#   'read',
#   'pencil',
#   'hand',
#   'mark',
#   'horrible',
#   'grammar',
#   'Please',
#   'waste',
#   'believe',
#   'good',
#   'reviews',
#   'must',
#   'written',
#   'author',
#   'put',
#   'much',
#   'faith',
#   'reviews'],
#  ['try',
#   'fool',
#   'us',
#   'fake',
#   'glaringly',
#   'obvious',
#   'glowing',
#   'reviews',
#   'written',
#   'person',
#   'perhaps',
#   'author',
#   'misspellings',
#   'poor',
#   'sentence',
#   'structure',
#   'featured',
#   'made',
#   'Veronica',
#   'Haddon',
#   'think',
#   'author'],
#  ['romantic',
#   'zen',
#   'baseball',
#   'comedy',
#   'hear',
#   'folks',
#   'say',
#   'make',
#   'like',
#   'anymore',
#   'might',
#   'talking',
#   'SEA',
#   'cool',
#   'story',
#   'young',
#   'Cuban',
#   'girl',
#   'searching',
#   'idenity',
#   'stumbles',
#   'coastal',
#   'resort',
#   'kitchen',
#   'gig',
#   'zen',
#   'motorcycle',
#   'maintenance',
#   'man',
#   'three',
#   'hysterical',
#   'Italian',
#   'chefs',
#   'Latino',
#   'fireballing',
#   'right',
#   'handed',
#   'pitcher',
#   'plays',
#   'team',
#   'sponsored',
#   'resort',
#   'often',
#   'case',
#   'honest',
#   'often',
#   'comical',
#   'always',
#   'emotional',
#   'interaction',
#   'sizzling',
#   'roster',
#   'perfect',
#   'mix',
#   'special',
#   'effects',
#   'salsa',
#   'sound',
#   'flashbacks',
#   'SEA',
#   'gets',
#   'BIG',
#   'stars'],
#  ['Fashionable',
#   'Compression',
#   'Stockings',
#   'DVT',
#   'doctor',
#   'required',
#   'wear',
#   'compression',
#   'wore',
#   'ugly',
#   'white',
#   'TED',
#   'hose',
#   'yucky',
#   'thick',
#   'brown',
#   'found',
#   'Jobst',
#   'gave',
#   'compression',
#   'needed',
#   'looked',
#   'like',
#   'regular',
#   'Even',
#   'though',
#   'blood',
#   'clot',
#   'gone',
#   'years',
#   'still',
#   'buy',
#   'wear',
#   'support',
#   'stockings',
#   'make',
#   'legs',
#   'feel',
#   'problems',
#   'rubberized',
#   'tops',
#   'rolling',
#   'tried',
#   'Jobst',
#   'adhesive',
#   'hated',
#   'skin',
#   'pulled',
#   'bought',
#   'inexpensive',
#   'garter',
#   'belt',
#   'works',
#   'fine',
#   'helps',
#   'keep',
#   'stockings',
#   'rolling'],
#  ['Jobst',
#   'UltraSheer',
#   'Thigh',
#   'High',
#   'Excellent',
#   'However',
#   'difficult',
#   'get',
#   'older',
#   'feel',
#   'like',
#   'full',
#   'day',
#   'workout',
#   'getting',
#   'Also',
#   'day',
#   'wears',
#   'begin',
#   'roll',
#   'top',
#   'create',
#   'deep',
#   'ridge',
#   'wear',
#   'two',
#   'difficulties',
#   'could',
#   'addressed',
#   'would',
#   'help'],
#  ['sizes',
#   'recomended',
#   'size',
#   'chart',
#   'real',
#   'sizes',
#   'much',
#   'smaller',
#   'recomended',
#   'tried',
#   'put',
#   'sheer',
#   'guess',
#   'buy',
#   'item',
#   'better',
#   'go',
#   'store',
#   'check'],
#  ['mens',
#   'ultrasheer',
#   'model',
#   'may',
#   'ok',
#   'sedentary',
#   'types',
#   'active',
#   'get',
#   'around',
#   'alot',
#   'job',
#   'consistently',
#   'found',
#   'stockings',
#   'rolled',
#   'ankles',
#   'Good',
#   'Solution',
#   'go',
#   'standard',
#   'compression',
#   'stocking',
#   'stock',
#   'Excellent',
#   'support',
#   'stays',
#   'gives',
#   'pair',
#   'also',
#   'tore',
#   'struggled',
#   'pull',
#   'Good',
#   'investment'],
#  ['Delicious',
#   'cookie',
#   'mix',
#   'thought',
#   'funny',
#   'bought',
#   'product',
#   'without',
#   'knowing',
#   'read',
#   'header',
#   'quickly',
#   'thought',
#   'packaged',
#   'cookie',
#   'MIX',
#   'guess',
#   'noticed',
#   'since',
#   'right',
#   'first',
#   'time',
#   'ever',
#   'tried',
#   'baking',
#   'cookie',
#   'used',
#   'convenience',
#   'cookie',
#   'dough',
#   'buy',
#   'wrapped',
#   'plastic',
#   'logs',
#   'might',
#   'bit',
#   'Mixing',
#   'dough',
#   'get',
#   'messy',
#   'extremely',
#   'sticky',
#   'However',
#   'cookie',
#   'mix',
#   'like',
#   'lot',
#   'flexibility',
#   'ratio',
#   'ingredients',
#   'like',
#   'add',
#   'extra',
#   'butter',
#   'make',
#   'baked',
#   'cookies',
#   'chewy',
#   'Also',
#   'mix',
#   'really',
#   'large',
#   'chocolate',
#   'chips',
#   'love',
#   'removed',
#   'star',
#   'addition',
#   'flavors',
#   'mix'],
#  ['Another',
#   'Abysmal',
#   'Digital',
#   'Copy',
#   'Rather',
#   'scratches',
#   'insect',
#   'droppings',
#   'one',
#   'random',
#   'pixelations',
#   'combined',
#   'muddy',
#   'light',
#   'vague',
#   'image',
#   'Probably',
#   'cue',
#   'packaging',
#   'straight',
#   'street',
#   'corner',
#   'bootleg',
#   'ever',
#   'seen',
#   'reasonably',
#   'good',
#   'condition',
#   'film',
#   'copy',
#   'know',
#   'defining',
#   'visuals',
#   'film',
#   'crystal',
#   'clear',
#   'lighting',
#   'contrasts',
#   'black',
#   'surrounding',
#   'countryside',
#   'home',
#   'scenes',
#   'set',
#   'early',
#   'morning',
#   'ground',
#   'mists',
#   'haze',
#   'memory',
#   'events',
#   'bridge',
#   'water',
#   'bright',
#   'clear',
#   'everything',
#   'dull',
#   'dark',
#   'remember',
#   'timbre',
#   'enunciation',
#   'Captain',
#   'commands',
#   'hard',
#   'believe',
#   'award',
#   'winning',
#   'critically',
#   'acclaimed',
#   'film',
#   'best',
#   'presentation',
#   'Somewhere',
#   'DVD',
#   'comes',
#   'standard',
#   'public',
#   'library',
#   'none',
#   'appear',
#   'Amazon'],
#  ['fascinating',
#   'insight',
#   'life',
#   'modern',
#   'Japanese',
#   'teens',
#   'thoroughly',
#   'enjoyed',
#   'Rising',
#   'Sons',
#   'know',
#   'book',
#   'looks',
#   'Japanese',
#   'society',
#   'point',
#   'view',
#   'young',
#   'people',
#   'poised',
#   'parents',
#   'Japanese',
#   'culture',
#   'restraint',
#   'obedience',
#   'community',
#   'peers',
#   'adulation',
#   'Western',
#   'True',
#   'form',
#   'New',
#   'Young',
#   'Japan',
#   'seem',
#   'creating',
#   'international',
#   'blend',
#   'Ando',
#   'family',
#   'demonstrates',
#   'beautifully',
#   'written',
#   'book',
#   'vignettes',
#   'private',
#   'lives',
#   'members',
#   'Steven',
#   'Wardell',
#   'clearly',
#   'talented',
#   'young',
#   'author',
#   'adopted',
#   'schooling',
#   'family',
#   'four',
#   'teens',
#   'thus',
#   'able',
#   'view',
#   'family',
#   'life',
#   'Japan',
#   'inside',
#   'great',
#   'read'],
#  ['liked',
#   'album',
#   'thought',
#   'would',
#   'heard',
#   'song',
#   'two',
#   'thought',
#   'listened',
#   'songs',
#   'like',
#   'blue',
#   'angel',
#   'lanna',
#   'hair',
#   'rose',
#   'trully',
#   'amazing',
#   'singer',
#   'talent',
#   'find',
#   'much',
#   'days'],
#  ['Problem',
#   'charging',
#   'smaller',
#   'AAAs',
#   'charger',
#   'two',
#   'charges',
#   'AA',
#   'batteries',
#   'fine',
#   'huge',
#   'problem',
#   'securing',
#   'smaller',
#   'AAA',
#   'charge',
#   'smaller',
#   'batteries',
#   'need',
#   'flip',
#   'little',
#   'button',
#   'positive',
#   'beginning',
#   'one',
#   'four',
#   'AAA',
#   'batteries',
#   'would',
#   'pop',
#   'three',
#   'four',
#   'wo',
#   'problem',
#   'flip',
#   'mechanism',
#   'became',
#   'loose',
#   'horizontal',
#   'pressure',
#   'would',
#   'push',
#   'buttons',
#   'back',
#   'using',
#   'duct',
#   'tape',
#   'segment',
#   'crayon',
#   'apply',
#   'crayon',
#   'buttons',
#   'wrap',
#   'tape',
#   'know',
#   'painful'],
#  ['Works',
#   'advertised',
#   'bought',
#   'one',
#   'instructions',
#   'say',
#   'lights',
#   'stay',
#   'battery',
#   'charges',
#   'instructions',
#   'doNT',
#   'say',
#   'lights',
#   'turn',
#   'also',
#   'hours',
#   'charging',
#   'lights',
#   'stay',
#   'returned',
#   'thinking',
#   'bad',
#   'new',
#   'one',
#   'kept',
#   'since',
#   'charge',
#   'lights',
#   'useless',
#   'since',
#   'seem',
#   'always',
#   'stay',
#   'backup',
#   'charger',
#   'manage',
#   'drain',
#   'AAs',
#   'would',
#   'want',
#   'charger'],
#  ['Disappointed',
#   'read',
#   'reviews',
#   'made',
#   'purchase',
#   'charger',
#   'convenient',
#   'charging',
#   'four',
#   'batteries',
#   'charge',
#   'lasts',
#   'short',
#   'go',
#   'find',
#   'batteries',
#   'give',
#   'longer',
#   'life',
#   'kodak',
#   'NiMH',
#   'AA',
#   'batteries'],
#  ['Oh',
#   'dear',
#   'excited',
#   'find',
#   'book',
#   'ostensibly',
#   'Muslim',
#   'feminism',
#   'volume',
#   'live',
#   'essay',
#   'among',
#   'things',
#   'describes',
#   'veil',
#   'potentially',
#   'begin',
#   'explain',
#   'Muslim',
#   'women',
#   'Cape',
#   'Town',
#   'claims',
#   'Muslim',
#   'women',
#   'separate',
#   'Gee',
#   'whiz',
#   'expected',
#   'hoped',
#   'least',
#   'one',
#   'Muslim',
#   'feminist',
#   'condemnation',
#   'gender',
#   'single',
#   'one',
#   'surprised',
#   'essay',
#   'extolling',
#   'virtues',
#   'female',
#   'genital',
#   'Alyssa',
#   'Lappen'],
#  ['Based',
#   'reviews',
#   'bought',
#   'one',
#   'glad',
#   'early',
#   'Christmas',
#   'present',
#   'deciding',
#   'join',
#   'rest',
#   'world',
#   'wanting',
#   'let',
#   'go',
#   'VHS',
#   'movies',
#   'quite',
#   'Based',
#   'reviews',
#   'price',
#   'JVC',
#   'TV',
#   'agree',
#   'easy',
#   'bit',
#   'awkward',
#   'work',
#   'whole',
#   'selection',
#   'options',
#   'think',
#   'gotten',
#   'hang',
#   'comments',
#   'intuitive',
#   'actually',
#   'pretty',
#   'complicated',
#   'many',
#   'buttons',
#   'remote',
#   'might',
#   'please',
#   'others',
#   'rely',
#   'heavily',
#   'setting',
#   'VCR',
#   'timer',
#   'awkward',
#   'ca',
#   'enter',
#   'start',
#   'end',
#   'time',
#   'scroll',
#   'unless',
#   'missing',
#   'something',
#   'good',
#   'product'],
#  ['Incorrect',
#   'disc',
#   'big',
#   'JVC',
#   'fan',
#   'like',
#   'model',
#   'suspiscious',
#   'saw',
#   'several',
#   'units',
#   'return',
#   'section',
#   'bought',
#   'one',
#   'anyway',
#   'new',
#   'must',
#   'say',
#   'unit',
#   'sends',
#   'clicks',
#   'receiver',
#   'transition',
#   'scenes',
#   'always',
#   'smooth',
#   'like',
#   'little',
#   'pause',
#   'still',
#   'fairly',
#   'new',
#   'ca',
#   'get',
#   'DVD',
#   'CD',
#   'even',
#   'DVD',
#   'headcleaner',
#   'get',
#   'incorrect',
#   'disc',
#   'message'],
#  ['happy',
#   'JVC',
#   'nut',
#   'JVC',
#   'televisions',
#   'one',
#   'VCR',
#   'one',
#   'bookshelf',
#   'audio',
#   'system',
#   'car',
#   'audio',
#   'came',
#   'time',
#   'move',
#   'VCR',
#   'player',
#   'boys',
#   'room',
#   'get',
#   'another',
#   'one',
#   'old',
#   'man',
#   'knew',
#   'make',
#   'going',
#   'decided',
#   'combo',
#   'player',
#   'think',
#   'VHS',
#   'going',
#   'around',
#   'much',
#   'like',
#   'combo',
#   'player',
#   'except',
#   'things',
#   'cable',
#   'box',
#   'compatability',
#   'remote',
#   'control',
#   'seperate',
#   'audio',
#   'video',
#   'inputs',
#   'input',
#   'coax',
#   'cable',
#   'cable',
#   'box',
#   'cable',
#   'programming',
#   'mono',
#   'wife',
#   'ca',
#   'tell',
#   'difference',
#   'sound',
#   'happy',
#   'live',
#   'VCR',
#   'DVD',
#   'look',
#   'sound',
#   'GREAT'],
#  ['titled',
#   'Hollywood',
#   'Debacle',
#   'plot',
#   'ridiculous',
#   'wonder',
#   'even',
#   'read',
#   'script',
#   'making',
#   'mountain',
#   'lion',
#   'breaks',
#   'trailer',
#   'cars',
#   'behind',
#   'notice',
#   'mountain',
#   'lion',
#   'captured',
#   'put',
#   'jail',
#   'cell',
#   'Get',
#   'real',
#   'Utterly',
#   'completely',
#   'stupid'],
#  ['great',
#   'TV',
#   'bet',
#   'Hotel',
#   'Babylon',
#   'good',
#   'TV',
#   'great',
#   'TV',
#   'show',
#   'features',
#   'incredible',
#   'acting',
#   'Tamzin',
#   'Outhwaite',
#   'formerly',
#   'EastEnders',
#   'BBC',
#   'soap',
#   'Max',
#   'Beesley',
#   'movie',
#   'Glitter',
#   'starring',
#   'Mariah',
#   'Carey',
#   'show',
#   'could',
#   'make',
#   'great',
#   'drama',
#   'series',
#   'felt',
#   'mix',
#   'drama',
#   'comedy',
#   'soap',
#   'opera',
#   'mixed',
#   'great',
#   'BBC',
#   'show',
#   'aired',
#   'BBC',
#   'America',
#   'get',
#   'around',
#   'seeing',
#   'say',
#   'got',
#   'DVD',
#   'set',
#   'episodes',
#   'season',
#   'finale',
#   'interesting',
#   'show',
#   'reminds',
#   'Hotel',
#   'aired',
#   'ABC',
#   'reason',
#   'Hotel',
#   'set',
#   'fictional',
#   'San',
#   'Francisco',
#   'hotel',
#   'Hotel',
#   'Babylon',
#   'set',
#   'luxury',
#   'hotel',
#   'recommend',
#   'DVD',
#   'anyone',
#   'willing',
#   'watch',
#   'great',
#   'show',
#   'BBC'],
#  ['Nothing',
#   'already',
#   'know',
#   'even',
#   'casually',
#   'looked',
#   'applying',
#   'law',
#   'school',
#   'already',
#   'read',
#   'everything',
#   'book',
#   'waste',
#   'money',
#   'seriously'],
#  ['Unfortunately',
#   'entertaining',
#   'least',
#   'first',
#   'ordered',
#   'CD',
#   'figured',
#   'going',
#   'hip',
#   'cool',
#   'daddy',
#   'vibe',
#   'However',
#   'much',
#   'dismay',
#   'sounds',
#   'like',
#   'fourth',
#   'grade',
#   'music',
#   'main',
#   'jist',
#   'CD',
#   'xylaphone',
#   'playing',
#   'peoples',
#   'voices',
#   'trying',
#   'replicate',
#   'happening',
#   'believe',
#   'played',
#   'CD',
#   'party',
#   'anywhere',
#   'neighborhood',
#   'would',
#   'get',
#   'laughed',
#   'Growing',
#   'surfer',
#   'San',
#   'Diego',
#   'would',
#   'recommend',
#   'CD',
#   'Southern',
#   'California',
#   'Honestly',
#   'played',
#   'kinda',
#   'felt',
#   'bad',
#   'B',
#   'absolutle',
#   'epitimy',
#   'CD',
#   'last',
#   'vibe',
#   'Surf',
#   'Cha',
#   'Surfers',
#   'CHA'],
#  ['Rochelle',
#   'explains',
#   'Wondering',
#   'hell',
#   'happened',
#   'moral',
#   'aspect',
#   'modern',
#   'American',
#   'culture',
#   'book',
#   'lucid',
#   'well',
#   'argued',
#   'explanation',
#   'simple',
#   'fact',
#   'become',
#   'totally',
#   'focused',
#   'individual',
#   'RIGHTS',
#   'completely',
#   'ignored',
#   'even',
#   'mocked',
#   'personal',
#   'public',
#   'final',
#   'response',
#   'indictment',
#   'Robert',
#   'Ringer',
#   'best',
#   'seller',
#   'LOOKING',
#   'great',
#   'time',
#   'anyone',
#   'disgusted',
#   'boorish',
#   'state',
#   'American',
#   'media',
#   'politics',
#   'discourse',
#   'general',
#   'clear',
#   'heads',
#   'substantial',
#   'challenges',
#   'lie',
#   'us',
#   'Americans',
#   'human',
#   'great',
#   'book'],
#  ['great',
#   'playing',
#   'Larry',
#   'work',
#   'Muse',
#   'label',
#   'late',
#   'early',
#   'found',
#   'exploring',
#   'rich',
#   'catalog',
#   'jazz',
#   'standards',
#   'probably',
#   'grew',
#   'Surrounding',
#   'best',
#   'musicians',
#   'around',
#   'Larry',
#   'sounds',
#   'relaxed',
#   'focused',
#   'totally',
#   'Listen',
#   'Larry',
#   'take',
#   'Funny',
#   'Valentine',
#   'tell',
#   'stand',
#   'right',
#   'Chet',
#   'Baker',
#   'fine',
#   'album',
#   'enjoy'],
#  ['work',
#   'Mac',
#   'clearly',
#   'says',
#   'line',
#   'work',
#   'Mac',
#   'OS',
#   'disk',
#   'comes',
#   'Windows',
#   'order',
#   'Mac'],
#  ['Frustrating',
#   'three',
#   'year',
#   'old',
#   'son',
#   'excited',
#   'get',
#   'two',
#   'attempts',
#   'playing',
#   'touched',
#   'able',
#   'use',
#   'mouse',
#   'games',
#   'except',
#   'segments',
#   'instead',
#   'using',
#   'arrows',
#   'keyboard',
#   'hard',
#   'much',
#   'disapointed',
#   'game',
#   'wish',
#   'could',
#   'return'],
#  ['Mind',
#   'numbing',
#   'game',
#   'makes',
#   'things',
#   'never',
#   'holds',
#   'son',
#   'attention',
#   'long',
#   'enough',
#   'get',
#   'next',
#   'choice',
#   'games',
#   'every',
#   'thing',
#   'another',
#   'Rescue',
#   'Heroes',
#   'game',
#   'boys',
#   'love',
#   'one',
#   'dog'],
#  ['recommend',
#   'former',
#   'Alaskan',
#   'want',
#   'repeatedly',
#   'attempting',
#   'Allman',
#   'recipes',
#   'throw',
#   'cups',
#   'flour',
#   'miscellaneous',
#   'ingredients',
#   'nearly',
#   'every',
#   'time',
#   'comparing',
#   'Ed',
#   'Wood',
#   'recipes',
#   'work',
#   'flawlessly',
#   'Lisa',
#   'Rayner',
#   'excellent',
#   'Wild',
#   'Bread',
#   'sourdough',
#   'artisan',
#   'breads',
#   'kitchen',
#   'ca',
#   'help',
#   'notice',
#   'recipes',
#   'work',
#   'Allman',
#   'novice',
#   'thing',
#   'worked',
#   'reliably',
#   'pancakes',
#   'recipe',
#   'found',
#   'places',
#   'looking',
#   'reliable',
#   'recipes',
#   'concise',
#   'information',
#   'starting',
#   'sourdough',
#   'maintaining',
#   'recommend',
#   'Ed',
#   'Wood',
#   'books',
#   'even',
#   'old',
#   'Lisa',
#   'Rayner',
#   'written',
#   'fabulous',
#   'tome',
#   'Wild',
#   'pass',
#   'historical',
#   'vignettes',
#   'interesting',
#   'enough',
#   'warrant',
#   'cost',
#   'Check',
#   'library',
#   'must'],
#  ['Alaska',
#   'sourdough',
#   'REad',
#   'book',
#   'visiting',
#   'brother',
#   'Loved',
#   'going',
#   'making',
#   'sourdough',
#   'starter',
#   'Book',
#   'full',
#   'great',
#   'stories',
#   'recipes'],
#  ['Old',
#   'good',
#   'book',
#   'worth',
#   'keep',
#   'collection',
#   'advise',
#   'sourdough',
#   'Ruth',
#   'also',
#   'told',
#   'picture',
#   'past',
#   'years',
#   'ago',
#   'Alaska',
#   'stand',
#   'mixer',
#   'civilized',
#   'stuffs',
#   'kitchen',
#   'pot',
#   'sourdough'],
#  ['autumn',
#   'got',
#   'daughter',
#   'NC',
#   'making',
#   'prefect',
#   'Wish',
#   'lived',
#   'closer',
#   'make'],
#  ['Fast',
#   'download',
#   'music',
#   'waxed',
#   'decades',
#   'ago',
#   'One',
#   'songs',
#   'played',
#   'background',
#   'music',
#   'YouTube',
#   'video',
#   'kind',
#   'gymnastic',
#   'dance',
#   'feat',
#   'hunted',
#   'melody',
#   'read',
#   'English',
#   'lyrics',
#   'decided',
#   'see',
#   'else',
#   'Downloaded',
#   'full',
#   'album',
#   'via',
#   'Amazon',
#   'downloader',
#   'happily',
#   'listen',
#   'melodies',
#   'interspersed',
#   'iPod'],
#  ['Maybe',
#   'got',
#   'bad',
#   'experience',
#   'got',
#   'FM',
#   'DVD',
#   'player',
#   'rattled',
#   'pretty',
#   'loudly',
#   'sometimes',
#   'always',
#   'put',
#   'tried',
#   'picture',
#   'quality',
#   'great',
#   'screen',
#   'got',
#   'horizontal',
#   'line',
#   'thru',
#   'middle',
#   'short',
#   'time',
#   'would',
#   'go',
#   'Plus',
#   'one',
#   'reviewers',
#   'dead',
#   'remote',
#   'layout',
#   'makes',
#   'sense',
#   'poor',
#   'human',
#   'engineering',
#   'brought',
#   'back',
#   'store',
#   'saw',
#   'model',
#   'Emerson',
#   'name',
#   'WM',
#   'hesitant',
#   'buy'],
#  ['Sylvania',
#   'Flat',
#   'Panel',
#   'LCD',
#   'TV',
#   'Built',
#   'DVD',
#   'player',
#   'Light',
#   'weight',
#   'space',
#   'saving',
#   'attractive',
#   'Sharp',
#   'Picture',
#   'Good',
#   'sound',
#   'quality',
#   'quick',
#   'response',
#   'DVD',
#   'playback',
#   'also',
#   'negative',
#   'remote',
#   'hard',
#   'read',
#   'functions',
#   'keys',
#   'due',
#   'color',
#   'placement',
#   'keys',
#   'almost',
#   'illogical',
#   'look',
#   'carefully',
#   'almost',
#   'seems',
#   'like',
#   'designed',
#   'quality',
#   'features',
#   'price',
#   'still',
#   'makes',
#   'TV',
#   'excellent',
#   'buy'],
#  ['TERRIBLE',
#   'BUY',
#   'bought',
#   'wife',
#   'birthday',
#   'toreturn',
#   'DVD',
#   'palyer',
#   'would',
#   'returned',
#   'got',
#   'repalcement',
#   'DVD',
#   'player',
#   'failed',
#   'work',
#   'piece',
#   'junk'],
#  ['BEWARE',
#   'TV',
#   'set',
#   'capable',
#   'recall',
#   'want',
#   'flash',
#   'back',
#   'channels',
#   'TV',
#   'going',
#   'give',
#   'remote',
#   'control',
#   'comes',
#   'TV',
#   'recall',
#   'function',
#   'bought',
#   'Sony',
#   'universal',
#   'much',
#   'better',
#   'remote',
#   'recall',
#   'button',
#   'However',
#   'soon',
#   'learned',
#   'TV',
#   'set',
#   'factory',
#   'capability',
#   'may',
#   'big',
#   'deal',
#   'user',
#   'found',
#   'annoying'],
#  ['Kitchen',
#   'TV',
#   'bought',
#   'replace',
#   'tube',
#   'tv',
#   'gained',
#   'larger',
#   'screen',
#   'plus',
#   'relcaiming',
#   'counter',
#   'picture',
#   'good',
#   'internal',
#   'DVD',
#   'player',
#   'good',
#   'purchase'],
#  ['Nice',
#   'money',
#   'first',
#   'one',
#   'bought',
#   'DVD',
#   'work',
#   'purchased',
#   'Electronics',
#   'Express',
#   'contacted',
#   'gave',
#   'RMA',
#   'number',
#   'right',
#   'away',
#   'Fedex',
#   'picked',
#   'next',
#   'day',
#   'new',
#   'one',
#   'arrived',
#   'week',
#   'one',
#   'really',
#   'love',
#   'clarity',
#   'complaint',
#   'DVD',
#   'mode',
#   'sound',
#   'loud',
#   'RV',
#   'running',
#   'barely',
#   'hear',
#   'solved',
#   'problem',
#   'running',
#   'audio',
#   'jack',
#   'TV',
#   'input',
#   'RV',
#   'stereo',
#   'speaker',
#   'lightweight',
#   'easy',
#   'move',
#   'around',
#   'bonus',
#   'remote',
#   'great',
#   'works',
#   'fine',
#   'jacks',
#   'antenna',
#   'input',
#   'easy',
#   'get',
#   'DVD',
#   'great',
#   'deal',
#   'price'],
#  ['Disappointed',
#   'Romanian',
#   'book',
#   'opinion',
#   'biased',
#   'takes',
#   'angle',
#   'Europe',
#   'clean',
#   'proper',
#   'fails',
#   'shed',
#   'light',
#   'rest',
#   'understand',
#   'tourist',
#   'guides',
#   'would',
#   'anyone',
#   'want',
#   'tour',
#   'country',
#   'forgotten',
#   'However',
#   'disappointed',
#   'Romanian',
#   'book',
#   'would',
#   'never',
#   'use',
#   'seen',
#   'travel',
#   'guides',
#   'outlining',
#   'Europe',
#   'exclude',
#   'Romania',
#   'precision',
#   'detail',
#   'DK',
#   'series',
#   'left',
#   'yet',
#   'disappointment'],
#  ['Great',
#   'travel',
#   'guide',
#   'Europe',
#   'book',
#   'realy',
#   'great',
#   'everybody',
#   'likes',
#   'travel',
#   'combination',
#   'good',
#   'pictures',
#   'illustration',
#   'texts',
#   'get',
#   'good',
#   'overall',
#   'view',
#   'important',
#   'sights',
#   'places',
#   'cities',
#   'countries',
#   'Europe',
#   'also',
#   'bit',
#   'historical',
#   'European',
#   'already',
#   'traveled',
#   'bit',
#   'still',
#   'could',
#   'find',
#   'lot',
#   'inspiration',
#   'interesting',
#   'places',
#   'Thank',
#   'lot',
#   'Eyewitness',
#   'Travel',
#   'great',
#   'books'],
#  ['best',
#   'bought',
#   'lonely',
#   'planet',
#   'used',
#   'lonely',
#   'planet',
#   'book',
#   'full',
#   'pictures',
#   'give',
#   'info',
#   'Also',
#   'ended',
#   'buying',
#   'indiv',
#   'city',
#   'guide',
#   'well',
#   'one',
#   'scratches',
#   'surface'],
#  ['Good',
#   'received',
#   'defective',
#   'book',
#   'bought',
#   'book',
#   'moving',
#   'Germany',
#   'wanted',
#   'get',
#   'good',
#   'overview',
#   'countries',
#   'Europe',
#   'could',
#   'travel',
#   'Unfortunately',
#   'pages',
#   'Greece',
#   'English',
#   'looks',
#   'sort',
#   'printing',
#   'problem',
#   'found',
#   'rest',
#   'book',
#   'give',
#   'good',
#   'highlights',
#   'countries'],
#  ['Label',
#   'Memphis',
#   'comes',
#   'Reatards',
#   'fronted',
#   'course',
#   'wild',
#   'kid',
#   'Jay',
#   'starting',
#   'Eric',
#   'Oblivians',
#   'label',
#   'Goner',
#   'tender',
#   'age',
#   'Jay',
#   'still',
#   'rocking',
#   'offending',
#   'sensibilities',
#   'Overdriven',
#   'loud',
#   'crackling',
#   'guitars',
#   'underlaying',
#   'Jay',
#   'southern',
#   'crooning',
#   'howl',
#   'energizes',
#   'amazing',
#   'song',
#   'writing',
#   'heard',
#   'years'],
#  ['Either',
#   'Depends',
#   'look',
#   'Either',
#   'Depends',
#   'look',
#   'Star',
#   'sent',
#   'feet',
#   'OD',
#   'copper',
#   'Star',
#   'wo',
#   'accept',
#   'returns',
#   'stars',
#   'figure',
#   'actually',
#   'worth',
#   'since',
#   'wo',
#   'take',
#   'return',
#   'figure',
#   'sell',
#   'make',
#   'deal'],
#  ['Hunting',
#   'Hard',
#   'Way',
#   'Thia',
#   'gift',
#   'Husband',
#   'loved',
#   'arrived',
#   'date',
#   'told',
#   'would'],
#  ['Disappointing',
#   'text',
#   'ever',
#   'think',
#   'plates',
#   'markedly',
#   'inferior',
#   'previous',
#   'known',
#   'ahead',
#   'time',
#   'would',
#   'purchased',
#   'volume'],
#  ['Homer',
#   'Moses',
#   'extremely',
#   'helpful',
#   'gem',
#   'complex',
#   'subject',
#   'second',
#   'century',
#   'religious',
#   'authority',
#   'textual',
#   'anyone',
#   'serious',
#   'period',
#   'interelation',
#   'cultures',
#   'book',
#   'complex',
#   'detailed',
#   'course',
#   'must',
#   'argue',
#   'buy',
#   'Yes',
#   'unless',
#   'want',
#   'keep',
#   'running',
#   'back',
#   'write',
#   'thoroughly',
#   'disagreeing',
#   'review'],
#  ['poor',
#   'screen',
#   'arrived',
#   'cardboard',
#   'box',
#   'pretty',
#   'beat',
#   'screen',
#   'lightweight',
#   'cheesy',
#   'finish',
#   'worn',
#   'across',
#   'entire',
#   'top',
#   'knew',
#   'solid',
#   'brass',
#   'expected',
#   'something',
#   'least',
#   'looked',
#   'decent',
#   'distance',
#   'price',
#   'paid'],
#  ['Scraped',
#   'across',
#   'whole',
#   'Purchased',
#   'screen',
#   'last',
#   'week',
#   'came',
#   'noticeable',
#   'scrapes',
#   'across',
#   'box',
#   'came',
#   'gigantic',
#   'plenty',
#   'packaging',
#   'material',
#   'screen',
#   'packaged',
#   'loosely',
#   'However',
#   'since',
#   'another',
#   'smaller',
#   'box',
#   'thinking',
#   'scraping',
#   'begin',
#   'Still',
#   'deciding',
#   'whether',
#   'go',
#   'trouble',
#   'exchanging',
#   'since',
#   'another',
#   'reviewer',
#   'said',
#   'would',
#   'want',
#   'risk',
#   'getting',
#   'another',
#   'damage',
#   'really',
#   'need',
#   'screen',
#   'right',
#   'damage',
#   'nice',
#   'screen'],
#  ['unknown',
#   'Africa',
#   'expect',
#   'music',
#   'africa',
#   'profesionally',
#   'white',
#   'world',
#   'understand',
#   'lyrics',
#   'understand',
#   'music',
#   'mixture',
#   'salsa',
#   'soukous',
#   'fado',
#   'always',
#   'african',
#   'feeling',
#   'soft',
#   'almost',
#   'borred',
#   'voice',
#   'Oliver',
#   'fits',
#   'pefectly',
#   'CD',
#   'recorded',
#   'France',
#   'Paris',
#   'hear',
#   'professionals',
#   'working',
#   'must',
#   'hot',
#   'lazy',
#   'Arno',
#   'Amsterdam'],
#  ['live',
#   'ordered',
#   'shoes',
#   'replace',
#   'previous',
#   'pair',
#   'ripped',
#   'apart',
#   'Clark',
#   'said',
#   'make',
#   'shoe',
#   'anymore',
#   'order',
#   'Sadly',
#   'second',
#   'pair',
#   'ripped',
#   'place',
#   'within',
#   'son',
#   'since',
#   'bought',
#   'similar',
#   'pair',
#   'Sperry',
#   'seem',
#   'holding',
#   'much',
#   'better'],
#  ['Profound',
#   'Truly',
#   'horrible',
#   'narrative',
#   'style',
#   'work',
#   'famous',
#   'founders',
#   'biographer',
#   'John',
#   'Morse',
#   'arrogant',
#   'flippant',
#   'frequently',
#   'carries',
#   'tone',
#   'amateur',
#   'Yankee',
#   'historian',
#   'high',
#   'passing',
#   'judgment',
#   'Southern',
#   'statesman',
#   'neither',
#   'Boston',
#   'Harvard',
#   'Perhaps',
#   'considered',
#   'penetrating',
#   'day',
#   'really',
#   'represents',
#   'nothing',
#   'opinion',
#   'research',
#   'thin',
#   'one',
#   'must',
#   'conclude',
#   'Morse',
#   'wrote',
#   'entire',
#   'manuscript',
#   'essentially',
#   'memory',
#   'little',
#   'reference',
#   'primary',
#   'secondary',
#   'sources',
#   'expect',
#   'historians',
#   'fact',
#   'Morse',
#   'wrote',
#   'piece',
#   'years',
#   'ago',
#   'rated',
#   'one',
#   'star'],
#  ['Definitely',
#   'enjoyed',
#   'gift',
#   'yr',
#   'old',
#   'big',
#   'Barbie',
#   'fan',
#   'well',
#   'loves',
#   'use',
#   'still',
#   'enjoying',
#   'completed',
#   'hours',
#   'worried',
#   'first',
#   'loves',
#   'music',
#   'enjoyable',
#   'colors',
#   'seems',
#   'user',
#   'friendly',
#   'also',
#   'daughter',
#   'really',
#   'needed',
#   'help',
#   'use',
#   'started',
#   'first',
#   'time'],
#  ['Even',
#   'Mommy',
#   'fun',
#   'one',
#   'four',
#   'year',
#   'old',
#   'daughter',
#   'loves',
#   'everything',
#   'Barbie',
#   'loves',
#   'Rapunzel',
#   'game',
#   'tons',
#   'fun',
#   'even',
#   'year',
#   'love',
#   'playing',
#   'love',
#   'decorating',
#   'rooms',
#   'finding',
#   'even',
#   'better',
#   'play',
#   'alone',
#   'get',
#   'time'],
#  ['Great',
#   'combination',
#   'creativity',
#   'adventure',
#   'year',
#   'old',
#   'daughter',
#   'addicted',
#   'plays',
#   'loves',
#   'opening',
#   'song',
#   'singing',
#   'non',
#   'gets',
#   'excited',
#   'time',
#   'completes',
#   'room',
#   'finds',
#   'gem',
#   'loves',
#   'solving',
#   'maze',
#   'find',
#   'Prince',
#   'problem',
#   'sings',
#   'song',
#   'much',
#   'ca',
#   'get',
#   'head'],
#  ['Rapunzel',
#   'great',
#   'game',
#   'year',
#   'old',
#   'son',
#   'year',
#   'old',
#   'daughter',
#   'love',
#   'like',
#   'play',
#   'would',
#   'let',
#   'much',
#   'fun',
#   'decorating',
#   'rooms',
#   'many',
#   'choices',
#   'keep',
#   'playing',
#   'Great',
#   'would',
#   'think',
#   'Barbie',
#   'game',
#   'would',
#   'Great',
#   'fun'],
#  ['expected',
#   'daughter',
#   'loved',
#   'years',
#   'old',
#   'took',
#   'hours',
#   'complete',
#   'Absolutely',
#   'challenge',
#   'little',
#   'essentially',
#   'clicking',
#   'screen',
#   'make',
#   'play',
#   'scenes',
#   'games',
#   'play',
#   'nothing',
#   'figure',
#   'nothing',
#   'Save',
#   'money'],
#  ['barbie',
#   'rapunzel',
#   'crying',
#   'child',
#   'old',
#   'daughter',
#   'currently',
#   'sobbing',
#   'bedroom',
#   'result',
#   'rotten',
#   'spent',
#   'hour',
#   'game',
#   'painting',
#   'pretty',
#   'pictures',
#   'coloring',
#   'halfway',
#   'game',
#   'program',
#   'hung',
#   'would',
#   'let',
#   'us',
#   'leave',
#   'room',
#   'click',
#   'anywhere',
#   'even',
#   'exit',
#   'game',
#   'start',
#   'back',
#   'frozen',
#   'one',
#   'spot',
#   'Barbie',
#   'disembodied',
#   'voice',
#   'urges',
#   'us',
#   'explore',
#   'somewhere',
#   'else',
#   'Standard',
#   'software',
#   'troubleshooting',
#   'rebooting',
#   'Vivendi',
#   'Games',
#   'support',
#   'site',
#   'currently',
#   'left',
#   'weeping',
#   'frustrating',
#   'child',
#   'understand',
#   'fault',
#   'game',
#   'wo',
#   'hoping',
#   'incompetent',
#   'software',
#   'programming',
#   'could',
#   'catch',
#   'bug',
#   'old',
#   'caught',
#   'first',
#   'time',
#   'maybe',
#   'care',
#   'problems',
#   'long',
#   'get',
#   'want',
#   'crying',
#   'little',
#   'girl',
#   'avoid',
#   'game'],
#  ['Barbie',
#   'Rapunzel',
#   'Creative',
#   'Adventure',
#   'purchased',
#   'software',
#   'year',
#   'old',
#   'granddaughter',
#   'loves',
#   'playing',
#   'lets',
#   'play',
#   'sometimes',
#   'always',
#   'like',
#   'come',
#   'plan',
#   'purchase',
#   'software',
#   'programs'],
#  ['Use',
#   'imagination',
#   'year',
#   'old',
#   'daughter',
#   'love',
#   'actually',
#   'fight',
#   'going',
#   'paint',
#   'pictures',
#   'choose',
#   'themes',
#   'game',
#   'allows',
#   'creative',
#   'use',
#   'imagination',
#   'decorating',
#   'room',
#   'castle',
#   'finding',
#   'missing',
#   'gems',
#   'prince',
#   'crown',
#   'gives',
#   'Rapunzel',
#   'power',
#   'find',
#   'Prince',
#   'Stephan',
#   'turned',
#   'stone',
#   'bring',
#   'back',
#   'music',
#   'animation',
#   'best',
#   'kids',
#   'software',
#   'seen',
#   'boring',
#   'adult',
#   'sometimes',
#   'like',
#   'play',
#   'without',
#   'many',
#   'variations',
#   'color',
#   'schemes',
#   'patterns',
#   'never',
#   'highly',
#   'recommend',
#   'girls',
#   'ages'],
#  ['good',
#   'ok',
#   'rental',
#   'game',
#   'pretty',
#   'exciting',
#   'nice',
#   'really',
#   'creative',
#   'one',
#   'bad',
#   'thing',
#   'one',
#   'castle',
#   'kids',
#   'decorate',
#   'done',
#   'whole',
#   'castle',
#   'basically',
#   'either',
#   'create',
#   'new',
#   'username',
#   'get',
#   'another',
#   'game',
#   'like',
#   'sister',
#   'finished',
#   'castle',
#   'hours',
#   'never',
#   'even',
#   'looked',
#   'game',
#   'nice',
#   'game',
#   'fun',
#   'really',
#   'worth',
#   'much',
#   'money'],
#  ['OS',
#   'X',
#   'MAC',
#   'CLASSIC',
#   'NEGATIVE',
#   'game',
#   'work',
#   'OS',
#   'X',
#   'requires',
#   'CD',
#   'ca',
#   'multiple',
#   'slow',
#   'tell',
#   'daughter',
#   'thinking',
#   'lot',
#   'access',
#   'CD',
#   'everytime',
#   'new',
#   'ca',
#   'view',
#   'openning',
#   'sequence',
#   'without',
#   'throwing',
#   'saved',
#   'game',
#   'tasks',
#   'controls',
#   'hard',
#   'user',
#   'friendly',
#   'even',
#   'CRASHES',
#   'jumpy',
#   'hard',
#   'tasks',
#   'easy',
#   'possible',
#   'use',
#   'grand',
#   'three',
#   'year',
#   'enough',
#   'patience',
#   'survive',
#   'multiple',
#   'trials',
#   'get',
#   'work'],
#  ['Bad',
#   'Deal',
#   'ordered',
#   'DVD',
#   'received',
#   'substitute',
#   'never',
#   'received',
#   'DVD',
#   'ordered',
#   'Importcds',
#   'Vendor',
#   'contacted',
#   'recieve',
#   'ca',
#   'rate',
#   'DVD',
#   'never',
#   'bother',
#   'send',
#   'back',
#   'would',
#   'cost',
#   'orginally',
#   'paid',
#   'future',
#   'watch',
#   'name',
#   'person',
#   'persons',
#   'buying',
#   'thought',
#   'good',
#   'understand',
#   'simple',
#   'mistake',
#   'get',
#   'response',
#   'good',
#   'businees',
#   'spend',
#   'hundreds',
#   'dollars',
#   'month',
#   'building',
#   'DVD',
#   'guess',
#   'careful',
#   'future'],
#  ['Smells',
#   'second',
#   'bottle',
#   'sheer',
#   'freesia',
#   'love',
#   'fragrance',
#   'light',
#   'delicate',
#   'sent',
#   'beautiful',
#   'like',
#   'summer',
#   'day'],
#  ['disappointed',
#   'perfume',
#   'AWFUL',
#   'Smells',
#   'nothing',
#   'like',
#   'gift',
#   'recipient',
#   'worst',
#   'ca',
#   'returned'],
#  ['Creepy',
#   'Wow',
#   'people',
#   'behind',
#   'jealousy',
#   'revenge',
#   'doors',
#   'open',
#   'prepared',
#   'find',
#   'behind'],
#  ['audio',
#   'options',
#   'non',
#   'existent',
#   'movie',
#   'better',
#   'expected',
#   'didnt',
#   'expect',
#   'non',
#   'existent',
#   'Thai',
#   'option',
#   'disc',
#   'menu',
#   'well',
#   'stated',
#   'package',
#   'Thai',
#   'soundtrack',
#   'matter',
#   'choose',
#   'Thai',
#   'English',
#   'English',
#   'get',
#   'exceptions',
#   'dubbing',
#   'ridiculous',
#   'best',
#   'dubbing',
#   'title',
#   'sub',
#   'review',
#   'covers',
#   'first',
#   'movie',
#   'two',
#   'may',
#   'remain',
#   'plastic',
#   'never',
#   'see',
#   'inside',
#   'dvd',
#   'shame',
#   'sham',
#   'purchase',
#   'claims',
#   'original',
#   'disapointed',
#   'offering',
#   'Tokyo',
#   'Shock'],
#  ['Sooo',
#   'JAMMIN',
#   'trill',
#   'Man',
#   'jammin',
#   'tracks',
#   'Pokey',
#   'first',
#   'official',
#   'record',
#   'sooo',
#   'Love',
#   'production',
#   'everything',
#   'real',
#   'nice',
#   'screwed',
#   'among',
#   'last',
#   'great',
#   'SUC',
#   'say',
#   'fallen',
#   'downsized',
#   'much',
#   'deaths',
#   'screw',
#   'Sad',
#   'ya',
#   'love',
#   'Tx',
#   'rap',
#   'got',
#   'ta',
#   'get',
#   'Somethin',
#   'kickback',
#   'blow',
#   'big',
#   'somethin',
#   'jam',
#   'underrated',
#   'right',
#   'wish',
#   'people',
#   'would',
#   'forget',
#   'check',
#   'happening',
#   'guess',
#   'sadly',
#   'almost',
#   'Pat',
#   'gone',
#   'hawk',
#   'gone',
#   'screw',
#   'Moe',
#   'Pimp',
#   'C',
#   'Big',
#   'Makes',
#   'Regardless',
#   'Pokey',
#   'still',
#   'alive',
#   'making',
#   'new',
#   'music',
#   'keeping',
#   'legacy',
#   'great',
#   'place',
#   'start',
#   'Classic',
#   'Love',
#   'man'],
#  ['Dirty',
#   'South',
#   'probably',
#   'best',
#   'southside',
#   'CD',
#   'ever',
#   'come',
#   'Pretty',
#   'much',
#   'every',
#   'song',
#   'guest',
#   'late',
#   'Fat',
#   'Pat',
#   'Botany',
#   'Boys',
#   'Big',
#   'Steve',
#   'Chris',
#   'Ward',
#   'many',
#   'southside',
#   'CD',
#   'always'],
#  ['Good',
#   'book',
#   'Well',
#   'written',
#   'chronicles',
#   'Farm',
#   'people',
#   'lived',
#   'Excellent',
#   'photos',
#   'kept',
#   'looking',
#   'photo',
#   'long',
#   'shewas'],
#  ['voices',
#   'farm',
#   'copy',
#   'book',
#   'love',
#   'ca',
#   'wait',
#   'til',
#   'revised',
#   'version',
#   'comes',
#   'weeks'],
#  ['Little',
#   'one',
#   'maid',
#   'Israel',
#   'Bill',
#   'Harvey',
#   'wonderful',
#   'gift',
#   'making',
#   'history',
#   'come',
#   'alive',
#   'book',
#   'awakens',
#   'sense',
#   'wonder',
#   'possiblility',
#   'real',
#   'relationship',
#   'God',
#   'follow',
#   'faithfulness',
#   'one',
#   'little',
#   'girl',
#   'ancient',
#   'Young',
#   'girls',
#   'ages',
#   'love',
#   'always',
#   'one',
#   'loved',
#   'treasures',
#   'real',
#   'Keeper'],
#  ['Drew',
#   'Air',
#   'book',
#   'drew',
#   'air',
#   'pretty',
#   'idea',
#   'someone',
#   'would',
#   'waste',
#   'time',
#   'writing',
#   'Boy',
#   'draw',
#   'read',
#   'book'],
#  ['comfy',
#   'run',
#   'big',
#   'like',
#   'title',
#   'Warm',
#   'comfy',
#   'run',
#   'size',
#   'wear',
#   'lounging',
#   'big',
#   'deal'],
#  ['Buyer',
#   'Beware',
#   'ordered',
#   'cake',
#   'topper',
#   'June',
#   'given',
#   'estimated',
#   'shipping',
#   'date',
#   'July',
#   'dates',
#   'came',
#   'went',
#   'cake',
#   'contacted',
#   'seller',
#   'twice',
#   'filed',
#   'claim',
#   'end',
#   'receiving',
#   'cake',
#   'topper',
#   'July',
#   'however',
#   'even',
#   'one',
#   'ordered',
#   'seller',
#   'refund',
#   'money',
#   'never',
#   'contacted',
#   'apologized',
#   'never',
#   'buy',
#   'anything',
#   'seller',
#   'looked',
#   'seller',
#   'feedback',
#   'person',
#   'done',
#   'wrong',
#   'buyer',
#   'beware'],
#  ['Ariel',
#   'Litte',
#   'Mermaid',
#   'pearl',
#   'kit',
#   'Arrived',
#   'quickly',
#   'cute',
#   'topper',
#   'however',
#   'would',
#   'bought',
#   'provide',
#   'instructions',
#   'listened',
#   'reviews',
#   'hoping',
#   'get',
#   'topper',
#   'BUY',
#   'annoyed',
#   'Ariel',
#   'idea',
#   'decorate',
#   'cake'],
#  ['instructions',
#   'included',
#   'trust',
#   'seller',
#   'Promised',
#   'item',
#   'Complete',
#   'Instructions',
#   'additional',
#   'pledge',
#   'Sweet',
#   'Graces',
#   'email',
#   'Supply',
#   'List',
#   'Instruction',
#   'sheets',
#   'purchase',
#   'ready',
#   'ahead',
#   'time',
#   'received',
#   'none',
#   'plastic',
#   'figurine',
#   'boot',
#   'Amazon',
#   'claims',
#   'nothing',
#   'help',
#   'contact',
#   'got',
#   'phone',
#   'number',
#   'Let',
#   'hope',
#   'yields',
#   'Meanwhile',
#   'wishing',
#   'listened',
#   'previous',
#   'feedback',
#   'unreliable',
#   'seller'],
#  ['SOULWAX',
#   'ignored',
#   'critics',
#   'consumers',
#   'alike',
#   'get',
#   'SOULWAX',
#   'around',
#   'since',
#   'released',
#   'rock',
#   'debut',
#   'defunct',
#   'Almo',
#   'Sounds',
#   'chock',
#   'full',
#   'radio',
#   'hits',
#   'got',
#   'attention',
#   'Many',
#   'DJs',
#   'bootlegs',
#   'return',
#   'band',
#   'last',
#   'year',
#   'MINUTE',
#   'critcs',
#   'consumers',
#   'alike',
#   'barely',
#   'took',
#   'notice',
#   'album',
#   'amazing',
#   'writing',
#   'production',
#   'sheer',
#   'Hopefully',
#   'Nite',
#   'Versions',
#   'cheeky',
#   'title',
#   'recalling',
#   'bands',
#   'like',
#   'Duran',
#   'Duran',
#   'used',
#   'release',
#   'Nite',
#   'Version',
#   'singles',
#   'clubs',
#   'garner',
#   'sales',
#   'attention',
#   'SOULWAX',
#   'songs',
#   'practically',
#   'leap',
#   'speakers',
#   'grab',
#   'neck',
#   'turn',
#   'head',
#   'make',
#   'Ca',
#   'wait',
#   'hear',
#   'TIGA',
#   'upcoming',
#   'Sexor',
#   'debut'],
#  ['OMG',
#   'Soulwax',
#   'owns',
#   'wow',
#   'like',
#   'amazing',
#   'album',
#   'Every',
#   'track',
#   'rocks',
#   'love',
#   'job',
#   'guysMusicChoice',
#   'played',
#   'whole',
#   'album',
#   'Saturday',
#   'jamming',
#   'whole',
#   'time',
#   'going',
#   'wow',
#   'thing',
#   'want',
#   'none',
#   'cause',
#   'wo',
#   'feel'],
#  ['Slow',
#   'dull',
#   'classical',
#   'style',
#   'movie',
#   'stars',
#   'slow',
#   'dull',
#   'classical',
#   'style',
#   'movie',
#   'young',
#   'Jason',
#   'Bateman',
#   'slow',
#   'dull',
#   'moments',
#   'bad',
#   'style',
#   'relief',
#   'background',
#   'music',
#   'annoying',
#   'kept',
#   'Though',
#   'attempts',
#   'movie',
#   'achieves',
#   'suggest',
#   'skipping',
#   'movie'],
#  ['Thank',
#   'Releasing',
#   'loved',
#   'movie',
#   'kid',
#   'happy',
#   'powers',
#   'decided',
#   'release',
#   'finally',
#   'want',
#   'see',
#   'great',
#   'movie'],
#  ['Worth',
#   'Time',
#   'book',
#   'wriiten',
#   'would',
#   'never',
#   'life',
#   'recommend',
#   'stories',
#   'lacked',
#   'mystery',
#   'leave',
#   'wanting',
#   'figure',
#   'culprit',
#   'good',
#   'thing',
#   'none',
#   'stories',
#   'took',
#   'ten',
#   'twelve',
#   'pages'],
#  ['fun',
#   'educational',
#   'Trains',
#   'shapes',
#   'pegs',
#   'winning',
#   'combination',
#   'guaranteed',
#   'make',
#   'child',
#   'parent',
#   'Good',
#   'starter',
#   'puzzle',
#   'yr',
#   'old',
#   'range'],
#  ['Ludicrous',
#   'silly',
#   'remember',
#   'getting',
#   'book',
#   'faintly',
#   'says',
#   'alot',
#   'opinion',
#   'Basically',
#   'entertain',
#   'lots',
#   'odd',
#   'ideas',
#   'theories',
#   'book',
#   'basically',
#   'silly'],
#  ['Artistry',
#   'think',
#   'Deodato',
#   'concerts',
#   'rich',
#   'used',
#   'real',
#   'strings',
#   'band',
#   'musicians',
#   'well',
#   'appreciate',
#   'John',
#   'Tropea',
#   'excelent',
#   'renditions',
#   'guitar'],
#  ['Caution',
#   'tracks',
#   'original',
#   'versions',
#   'whether',
#   'tracks',
#   'remastered',
#   'irrelevant'],
#  ['textbook',
#   'Book',
#   'shipped',
#   'quickly',
#   'excellent',
#   'condition',
#   'Easy',
#   'transaction',
#   'would',
#   'buy'],
#  ['great',
#   'book',
#   'Historical',
#   'romance',
#   'lovers',
#   'engaging',
#   'count',
#   'life',
#   'Tess',
#   'girl',
#   'young',
#   'age',
#   'washed',
#   'shore',
#   'Isle',
#   'memory',
#   'life',
#   'stays',
#   'old',
#   'caretakers',
#   'caretakers',
#   'dead',
#   'young',
#   'man',
#   'Colin',
#   'Macpherson',
#   'washes',
#   'Colin',
#   'takes',
#   'Tess',
#   'back',
#   'castle',
#   'helps',
#   'uncover',
#   'opposites',
#   'know',
#   'say',
#   'opposites',
#   'book',
#   'one',
#   'many',
#   'Avon',
#   'True',
#   'Romance',
#   'read',
#   'every',
#   'book',
#   'series',
#   'know',
#   'like',
#   'book',
#   'love',
#   'great',
#   'book',
#   'girls',
#   'still',
#   'romance',
#   'novel',
#   'call',
#   'trashy',
#   'romance',
#   'great',
#   'novel',
#   'fokr',
#   'getting',
#   'romance',
#   'novels'],
#  ['YES',
#   'got',
#   'book',
#   'expecting',
#   'much',
#   'man',
#   'wrong',
#   'loved',
#   'book',
#   'may',
#   'usually',
#   'tied',
#   'man',
#   'long',
#   'blond',
#   'hair',
#   'wearing',
#   'kilt',
#   'authors',
#   'really',
#   'made',
#   'Colin',
#   'enchanting',
#   'Tess',
#   'soft',
#   'sometimes',
#   'seems',
#   'guillible',
#   'remember',
#   'part',
#   'one',
#   'favorite',
#   'books',
#   'series'],
#  ['best',
#   'series',
#   'Tess',
#   'Lindsay',
#   'content',
#   'sole',
#   'occupant',
#   'remote',
#   'island',
#   'Colin',
#   'Macpherson',
#   'washes',
#   'ashore',
#   'life',
#   'solitude',
#   'gets',
#   'shaken',
#   'Tess',
#   'always',
#   'told',
#   'fear',
#   'strange',
#   'men',
#   'reluctantly',
#   'strikes',
#   'friendship',
#   'Soon',
#   'Tess',
#   'discovers',
#   'family',
#   'forgotten',
#   'courage',
#   'leave',
#   'island',
#   'start',
#   'new',
#   'life',
#   'beginning',
#   'book',
#   'amusing',
#   'end',
#   'decent',
#   'middle',
#   'big',
#   'plot',
#   'loses',
#   'much',
#   'believability',
#   'mostly',
#   'due',
#   'poor',
#   'new',
#   'characters',
#   'introduced',
#   'one',
#   'sided',
#   'behavior',
#   'lacks',
#   'Even',
#   'Tess',
#   'Colin',
#   'development',
#   'side',
#   'tracked',
#   'much',
#   'way',
#   'relationship',
#   'seems',
#   'awkward',
#   'writing',
#   'improve',
#   'towards',
#   'end',
#   'enough',
#   'save',
#   'Unless',
#   'heart',
#   'set',
#   'reading',
#   'books',
#   'series',
#   'skip',
#   'one'],
#  ['ADDONICS',
#   'PORTABLE',
#   'CD',
#   'DRIVE',
#   'disappointed',
#   'performance',
#   'disappointed',
#   'seems',
#   'underpowered',
#   'constantly',
#   'trying',
#   'read',
#   'CDs',
#   'half',
#   'time',
#   'going',
#   'try',
#   'return',
#   'Amazon'],
#  ['Uncomfortable',
#   'Big',
#   'pants',
#   'way',
#   'big',
#   'looked',
#   'sizes',
#   'larger',
#   'incredibly',
#   'would',
#   'uncomfortable',
#   'daughter',
#   'wear',
#   'day'],
#  ['authentic',
#   'first',
#   'encounter',
#   'Yoruba',
#   'say',
#   'CDs',
#   'really',
#   'However',
#   'book',
#   'short',
#   'particular',
#   'certain',
#   'aspects',
#   'details',
#   'grammar',
#   'nuances',
#   'someone',
#   'NEVER',
#   'spoke',
#   'Yoruba',
#   'anybody',
#   'ask',
#   'clue',
#   'leaves',
#   'lot',
#   'questions',
#   'unanswered',
#   'however',
#   'hopefully',
#   'Yoruba',
#   'brighter',
#   'note',
#   'would',
#   'like',
#   'add',
#   'book',
#   'good',
#   'job',
#   'giving',
#   'little',
#   'insight',
#   'Yoruba',
#   'people',
#   'Yoruba',
#   'culture',
#   'would',
#   'recommend',
#   'good',
#   'start',
#   'book',
#   'anyone',
#   'wants',
#   'learn',
#   'Yoruba',
#   'ca',
#   'go',
#   'wrong'],
#  ['best',
#   'agree',
#   'CDs',
#   'much',
#   'needed',
#   'help',
#   'since',
#   'would',
#   'impossible',
#   'pronnounce',
#   'Yoruba',
#   'tones',
#   'without',
#   'help',
#   'native',
#   'However',
#   'design',
#   'book',
#   'really',
#   'poor',
# ...
#   'score',
#   'never',
#   'saw',
#   'parts',
#   'move',
#   'like',
#   'Elvis',
#   'looks',
#   'Anyway',
#   'crossed',
#   'double',
#   'lines',
#   'Spinout',
#   'want',
#   'Simply',
#   'awful',
#   'mean',
#   'great',
#   'way'],
#  ['else',
#   'would',
#   'three',
#   'beautiful',
#   'women',
#   'Spinout',
#   'Elvis',
#   'playing',
#   'singing',
#   'race',
#   'car',
#   'driver',
#   'three',
#   'beautiful',
#   'women',
#   'want',
#   'race',
#   'aisle',
#   'Shelley',
#   'Fabares',
#   'Diane',
#   'McBain',
#   'Deborah',
#   'Looks',
#   'like',
#   'Elvis',
#   'tough',
#   'ca',
#   'decide',
#   'Spinout',
#   'find',
#   'two',
#   'veteran',
#   'stars',
#   'height',
#   'stardom',
#   'Cecil',
#   'Kellaway',
#   'Una',
#   'Merkel',
#   'one',
#   'last',
#   'Also',
#   'man',
#   'plays',
#   'Shelley',
#   'Fabares',
#   'father',
#   'Carl',
#   'Betz',
#   'also',
#   'starred',
#   'father',
#   'Donna',
#   'Reed',
#   'Show',
#   'try',
#   'knock',
#   'got',
#   'great',
#   'songs',
#   'title',
#   'tune',
#   'top',
#   'hit',
#   'treat',
#   'swinging',
#   'film',
#   'ca',
#   'understand',
#   'Elvis',
#   'wants',
#   'stay',
#   'single'],
#  ['Presley',
#   'Worst',
#   'Film',
#   'Spinout',
#   'represents',
#   'nadir',
#   'Elvis',
#   'Cinema',
#   'bad',
#   'sitcom',
#   'without',
#   'laugh',
#   'redeeming',
#   'features',
#   'memorable',
#   'songs',
#   'Back',
#   'Stop',
#   'Look',
#   'Buy',
#   'soundtrack',
#   'skip',
#   'movie'],
#  ['music',
#   'better',
#   'movie',
#   'SPINOUT',
#   'another',
#   'hard',
#   'movie',
#   'sit',
#   'thanks',
#   'weak',
#   'dialogue',
#   'even',
#   'weaker',
#   'plays',
#   'singing',
#   'race',
#   'car',
#   'driver',
#   'second',
#   'time',
#   'chased',
#   'three',
#   'include',
#   'spoiled',
#   'brat',
#   'Shelley',
#   'Fabares',
#   'erotic',
#   'author',
#   'Diane',
#   'McBain',
#   'drummer',
#   'Deborah',
#   'Walley',
#   'music',
#   'actually',
#   'listenable',
#   'Highlights',
#   'include',
#   'Stop',
#   'Look',
#   'Listen',
#   'Back',
#   'appears',
#   'sleepwalking',
#   'appearance',
#   'also',
#   'disturbing',
#   'slightly',
#   'overweight',
#   'hair',
#   'looks',
#   'like',
#   'big',
#   'black',
#   'ball',
#   'QUITE',
#   'worst',
#   'far',
#   'Buy',
#   'something',
#   'worthwhile',
#   'first'],
#  ['GOOD',
#   'SPIN',
#   'PRESLEY',
#   'Presley',
#   'best',
#   'vehicle',
#   'outing',
#   'allowed',
#   'act',
#   'anyway',
#   'appears',
#   'going',
#   'though',
#   'movie',
#   'songs',
#   'real',
#   'treat',
#   'either',
#   'seems',
#   'singing',
#   'everyone',
#   'including',
#   'music',
#   'come',
#   'sings',
#   'anyway',
#   'asked',
#   'movie',
#   'Presley',
#   'SAID'],
#  ['Spinout',
#   'husband',
#   'love',
#   'auto',
#   'racing',
#   'husband',
#   'loved',
#   'writing',
#   'review',
#   'much',
#   'Elvis',
#   'Presley',
#   'fan'],
#  ['Piece',
#   'junk',
#   'would',
#   'nifty',
#   'little',
#   'contraption',
#   'fact',
#   'ca',
#   'change',
#   'top',
#   'primary',
#   'impetus',
#   'buying',
#   'Handspring',
#   'Visor',
#   'lost',
#   'want',
#   'pay',
#   'shipping',
#   'new',
#   'stylus',
#   'Handspring',
#   'went',
#   'Best',
#   'Buy',
#   'purchased',
#   'change',
#   'top',
#   'fits',
#   'Visor',
#   'properly',
#   'entire',
#   'headpiece',
#   'falls',
#   'constantly',
#   'bottom',
#   'part',
#   'stylus',
#   'gets',
#   'stuck',
#   'Oh',
#   'mention',
#   'light',
#   'function',
#   'works',
#   'part',
#   'time',
#   'worth',
#   'time',
#   'effort'],
#  ['Works',
#   'easy',
#   'use',
#   'drop',
#   'fixed',
#   'number',
#   'drops',
#   'fixed',
#   'amount',
#   'water',
#   'measured',
#   'enclosed',
#   'test',
#   'tube',
#   'given',
#   'number',
#   'drops',
#   'use',
#   'listed',
#   'right',
#   'minutes',
#   'compare',
#   'color',
#   'water',
#   'color',
#   'chart',
#   'card',
#   'gives',
#   'nitrite',
#   'plenty',
#   'easy',
#   'could',
#   'even',
#   'easier',
#   'chart',
#   'bottle',
#   'need',
#   'extra',
#   'card',
#   'lying',
#   'around',
#   'test',
#   'stuck',
#   'gauge',
#   'water',
#   'got',
#   'value',
#   'never',
#   'seen',
#   'anything',
#   'like',
#   'expire',
#   'point'],
#  ['Great',
#   'Buy',
#   'item',
#   'arrived',
#   'well',
#   'packed',
#   'looks',
#   'exactly',
#   'like',
#   'picture',
#   'fairly',
#   'easy',
#   'assemble',
#   'sturdy',
#   'well',
#   'course',
#   'assembly',
#   'required',
#   'piece',
#   'furniture',
#   'put',
#   'together',
#   'looks',
#   'like',
#   'really',
#   'nice',
#   'quality',
#   'daughter',
#   'loves',
#   'sized',
#   'child',
#   'small',
#   'think',
#   'able',
#   'use',
#   'age',
#   'also',
#   'convenient',
#   'hole',
#   'back',
#   'hutch',
#   'computer',
#   'wire',
#   'poke',
#   'looked',
#   'item',
#   'EVERYWHERE',
#   'including',
#   'eBay',
#   'Amazon',
#   'cheapest',
#   'chair',
#   'comes',
#   'included',
#   'buy',
#   'extra',
#   'chair',
#   'separately'],
#  ['Great',
#   'Desk',
#   'best',
#   'kids',
#   'desk',
#   'find',
#   'almost',
#   'guarantee',
#   'comes',
#   'well',
#   'packaged',
#   'requires',
#   'little',
#   'wood',
#   'solid',
#   'cheap',
#   'particle',
#   'board',
#   'find',
#   'big',
#   'box',
#   'stores'],
#  ['good',
#   'quality',
#   'price',
#   'desk',
#   'really',
#   'good',
#   'size',
#   'overly',
#   'big',
#   'learned',
#   'reviews',
#   'chair',
#   'included',
#   'desk',
#   'purchase',
#   'order',
#   'chair',
#   'also',
#   'ordered',
#   'matching',
#   'bookcase',
#   'slightly',
#   'different',
#   'shade',
#   'white',
#   'nothing',
#   'noticeable',
#   'especially',
#   'since',
#   'rubbed',
#   'beeswax',
#   'bottom',
#   'drawer',
#   'slides',
#   'would',
#   'recommend',
#   'anyone',
#   'want',
#   'spend',
#   'fortune',
#   'still',
#   'wants',
#   'something',
#   'looks',
#   'nice'],
#  ['Great',
#   'desk',
#   'great',
#   'buy',
#   'Thanks',
#   'Amazon',
#   'bought',
#   'desk',
#   'seven',
#   'year',
#   'old',
#   'daughter',
#   'keep',
#   'lap',
#   'top',
#   'desk',
#   'perfect',
#   'size',
#   'sit',
#   'high',
#   'quality',
#   'easy',
#   'put',
#   'would',
#   'highly',
#   'recommend',
#   'product',
#   'others'],
#  ['Love',
#   'KidKraft',
#   'love',
#   'desk',
#   'fact',
#   'two',
#   'One',
#   'daughter',
#   'one',
#   'beautiful',
#   'flawless',
#   'go',
#   'together',
#   'sturdy',
#   'last',
#   'many',
#   'happy',
#   'purchase'],
#  ['Great',
#   'Value',
#   'Less',
#   'Money',
#   'searched',
#   'hi',
#   'low',
#   'desk',
#   'would',
#   'work',
#   'son',
#   'small',
#   'room',
#   'wanted',
#   'desk',
#   'made',
#   'wood',
#   'available',
#   'honey',
#   'finish',
#   'match',
#   'furniture',
#   'small',
#   'hutch',
#   'large',
#   'hutch',
#   'would',
#   'work',
#   'reasonable',
#   'Kidcraft',
#   'Avalon',
#   'Desk',
#   'perfect',
#   'took',
#   'one',
#   'star',
#   'realize',
#   'short',
#   'ok',
#   'yr',
#   'old',
#   'son',
#   'grows',
#   'afraid',
#   'outgrow',
#   'would',
#   'great',
#   'Kidcraft',
#   'offered',
#   'taller',
#   'replacement',
#   'legs',
#   'desk',
#   'could',
#   'raised',
#   'higher',
#   'child',
#   'feel',
#   'desk',
#   'sturdy',
#   'enough',
#   'go',
#   'child',
#   'college',
#   'short',
#   'height',
#   'Dear',
#   'Kidcraft',
#   'please',
#   'make',
#   'taller',
#   'replacement',
#   'legs',
#   'desk',
#   'normal',
#   'desk',
#   'height',
#   'later',
#   'years',
#   'making',
#   'Teen',
#   'kraft',
#   'desk',
#   'Thanks'],
#  ['nice',
#   'desk',
#   'definitely',
#   'worth',
#   'daughter',
#   'wanted',
#   'white',
#   'desk',
#   'hutch',
#   'picked',
#   'many',
#   'including',
#   'ordered',
#   'one',
#   'without',
#   'knowing',
#   'first',
#   'upset',
#   'hutch',
#   'assembled',
#   'loves',
#   'loves',
#   'little',
#   'cubbies',
#   'Everything',
#   'packaged',
#   'nicely',
#   'one',
#   'scratch',
#   'ding',
#   'funny',
#   'hardware',
#   'everything',
#   'needed',
#   'extras',
#   'separate',
#   'baggies',
#   'chair',
#   'put',
#   'together',
#   'replace',
#   'knob',
#   'blue',
#   'glass',
#   'knob',
#   'hardware',
#   'store',
#   'make',
#   'little',
#   'unique',
#   'guess',
#   'looks',
#   'free',
#   'supersaver',
#   'shipping',
#   'sales',
#   'tax',
#   'better',
#   'buy',
#   'Trust',
#   'looked'],
#  ['Satisfied',
#   'pleased',
#   'desk',
#   'able',
#   'assemble',
#   'fairly',
#   'easy',
#   'daughter',
#   'enjoying',
#   'desk',
#   'quite',
#   'sturdy',
#   'chair',
#   'delivery',
#   'product',
#   'expedited',
#   'Thank',
#   'much'],
#  ['Great',
#   'value',
#   'good',
#   'quality',
#   'product',
#   'Love',
#   'desk',
#   'chair',
#   'Bought',
#   'enjoying',
#   'using',
#   'arts',
#   'crafts',
#   'projects',
#   'well',
#   'good',
#   'quality',
#   'took',
#   'less',
#   'hour',
#   'put',
#   'together',
#   'definitely',
#   'sturdy',
#   'material',
#   'coming',
#   'mom',
#   'rambunctious',
#   'thing',
#   'see',
#   'kid',
#   'growing',
#   'high',
#   'chair',
#   'small',
#   'catered',
#   'younger',
#   'kids',
#   'would',
#   'say',
#   'probably',
#   'younger'],
#  ['good',
#   'enough',
#   'Popeye',
#   'always',
#   'keeps',
#   'fine',
#   'product',
#   'never',
#   'knows',
#   'palooka',
#   'wot',
#   'ai',
#   'square',
#   'gon',
#   'na',
#   'need',
#   'put',
#   'always',
#   'leaves',
#   'ya',
#   'strong',
#   'finish'],
#  ['Must',
#   'Aspects',
#   'Love',
#   'Devotees',
#   'huge',
#   'Aspects',
#   'Love',
#   'fan',
#   'extremely',
#   'excited',
#   'find',
#   'another',
#   'cast',
#   'sceptical',
#   'however',
#   'reading',
#   'reviews',
#   'listening',
#   'fears',
#   'put',
#   'wonderful',
#   'recording',
#   'possesses',
#   'brisk',
#   'conducting',
#   'deep',
#   'emotion',
#   'musical',
#   'felt',
#   'cast',
#   'extremely',
#   'dramatic',
#   'piece',
#   'well',
#   'listened',
#   'several',
#   'ALW',
#   'cast',
#   'recordings',
#   'feel',
#   'cast',
#   'must',
#   'Aspects',
#   'Love',
#   'devotees'],
#  ['Cheap',
#   'dangerous',
#   'Though',
#   'month',
#   'starting',
#   'puts',
#   'shards',
#   'sharp',
#   'plastic',
#   'searching',
#   'net',
#   'find',
#   'experience',
#   'unique',
#   'better',
#   'brands',
#   'include',
#   'Unicorn',
#   'recommended',
#   'famous',
#   'cooking',
#   'magazine',
#   'Peugeot',
#   'Firth',
#   'William',
#   'Bounds'],
#  ['Skip',
#   'buy',
#   'full',
#   'sized',
#   'version',
#   'one',
#   'makes',
#   'small',
#   'fine',
#   'grind',
#   'pepper',
#   'useful',
#   'cranking',
#   'away',
#   'thing',
#   'ten',
#   'minutes',
#   'get',
#   'enough',
#   'crushed',
#   'pepper',
#   'flavor',
#   'anything'],
#  ['Slow',
#   'bought',
#   'grinder',
#   'could',
#   'operated',
#   'one',
#   'However',
#   'disappointed',
#   'volume',
#   'pepper',
#   'puts',
#   'per',
#   'looking',
#   'good',
#   'wrist',
#   'strength',
#   'training',
#   'exerciser',
#   'grinder'],
#  ['Multilevel',
#   'marketing',
#   'meets',
#   'education',
#   'purchase',
#   'book',
#   'community',
#   'college',
#   'class',
#   'textbook',
#   'complete',
#   'science',
#   'sketchy',
#   'research',
#   'shoddy',
#   'huge',
#   'holes',
#   'logic',
#   'brushed',
#   'explanations',
#   'like',
#   'ca',
#   'prove',
#   'nearly',
#   'anything',
#   'empirically',
#   'education',
#   'straight',
#   'page',
#   'concepts',
#   'presented',
#   'interesting',
#   'since',
#   'Jensen',
#   'hold',
#   'doctorate',
#   'provides',
#   'almost',
#   'citations',
#   'claims',
#   'way',
#   'check',
#   'assertions',
#   'determine',
#   'theories',
#   'come',
#   'book',
#   'reads',
#   'like',
#   'multilevel',
#   'marketing',
#   'sales',
#   'fact',
#   'encouraged',
#   'share',
#   'friends',
#   'colleagues',
#   'directed',
#   'website',
#   'could',
#   'empty',
#   'bank',
#   'account',
#   'getting',
#   'certified',
#   'Jensen',
#   'unique',
#   'empirically',
#   'unproven',
#   'techniques'],
#  ['easy',
#   'read',
#   'practical',
#   'Jensen',
#   'saved',
#   'teachers',
#   'time',
#   'gathering',
#   'together',
#   'latest',
#   'information',
#   'brain',
#   'learning',
#   'much',
#   'made',
#   'scholarly',
#   'research',
#   'accessible',
#   'fun',
#   'wish',
#   'deadwood',
#   'school',
#   'would',
#   'least',
#   'read',
#   'book',
#   'hope',
#   'would',
#   'also',
#   'use',
#   'great',
#   'ideas',
#   'students',
#   'sake'],
#  ['Pop',
#   'psychology',
#   'worse',
#   'Jensen',
#   'wife',
#   'developed',
#   'veritable',
#   'cottage',
#   'industry',
#   'replete',
#   'workshops',
#   'seminars',
#   'presentations',
#   'publications',
#   'certifications',
#   'got',
#   'money',
#   'something',
#   'sell',
#   'centered',
#   'around',
#   'termed',
#   'learning',
#   'book',
#   'presents',
#   'little',
#   'pages',
#   'scientifically',
#   'unsubstantiated',
#   'claims',
#   'recommendations',
#   'example',
#   'claims',
#   'color',
#   'yellow',
#   'somehow',
#   'enhances',
#   'intellectual',
#   'performance',
#   'hence',
#   'classrooms',
#   'painted',
#   'yellow',
#   'however',
#   'offer',
#   'shred',
#   'evidence',
#   'back',
#   'claim',
#   'ridiculous',
#   'stuff',
#   'ever',
#   'make',
#   'print'],
#  ['Get',
#   'dead',
#   'horse',
#   'old',
#   'school',
#   'education',
#   'seeking',
#   'outline',
#   'education',
#   'needs',
#   'practice',
#   'child',
#   'left',
#   'behind',
#   'book',
#   'starting',
#   'point',
#   'people',
#   'flow',
#   'book',
#   'easy',
#   'follow',
#   'considers',
#   'research',
#   'findings',
#   'brain',
#   'learns',
#   'stages',
#   'Unlike',
#   'consider',
#   'brain',
#   'research',
#   'fad',
#   'know',
#   'application',
#   'knowledge',
#   'book',
#   'influential',
#   'changes',
#   'produce',
#   'positive',
#   'results',
#   'world',
#   'accountability',
#   'tools',
#   'Brain',
#   'Based',
#   'teaching',
#   'allow',
#   'students',
#   'teachers',
#   'solution',
#   'leveling',
#   'field',
#   'students',
#   'less',
#   'fortunate',
#   'environments',
#   'politicians',
#   'clueless',
#   'regards',
#   'obstacles',
#   'survivalists',
#   'poverty',
#   'highly',
#   'reccommend',
#   'book',
#   'wishing',
#   'get',
#   'dead',
#   'horse',
#   'provide',
#   'productive',
#   'environment',
#   'education',
#   'century'],
#  ['Easy',
#   'read',
#   'brain',
#   'information',
#   'book',
#   'purchased',
#   'PhD',
#   'level',
#   'easy',
#   'gives',
#   'practical',
#   'applications',
#   'latest',
#   'brain',
#   'note',
#   'lot',
#   'references',
#   'documented',
#   'within',
#   'text',
#   'Jensen',
#   'quotes',
#   'study',
#   'give',
#   'extensive',
#   'book',
#   'used',
#   'parents',
#   'read',
#   'child',
#   'brain',
#   'works',
#   'teachers',
#   'within',
#   'school',
#   'good',
#   'book',
#   'read',
#   'want',
#   'basic',
#   'information',
#   'brain',
#   'education',
#   'standpoint'],
#  ['Fuzzy',
#   'around',
#   'edges',
#   'read',
#   'first',
#   'pages',
#   'book',
#   'need',
#   'read',
#   'far',
#   'though',
#   'interesting',
#   'seems',
#   'writer',
#   'makes',
#   'lot',
#   'claims',
#   'rarely',
#   'sure',
#   'proven',
#   'kind',
#   'sentence',
#   'makes',
#   'queasy',
#   'Given',
#   'activations',
#   'happening',
#   'brain',
#   'physical',
#   'performance',
#   'probably',
#   'uses',
#   'precent',
#   'brain',
#   'one',
#   'activity',
#   'use',
#   'percent',
#   'brain',
#   'physical',
#   'performance',
#   'important'],
#  ['Brain',
#   'Based',
#   'Learning',
#   'New',
#   'Paradigm',
#   'Teaching',
#   'currently',
#   'reading',
#   'Kindle',
#   'version',
#   'book',
#   'easy',
#   'read',
#   'full',
#   'material',
#   'try',
#   'class',
#   'Unfortunately',
#   'page',
#   'numbers',
#   'correspond',
#   'paper',
#   'version',
#   'text',
#   'book',
#   'impossible',
#   'cite',
#   'material',
#   'page',
#   'really',
#   'unacceptable',
#   'text',
#   'one',
#   'thing',
#   'literature',
#   'book',
#   'even',
#   'would',
#   'better',
#   'physical',
#   'page',
#   'number',
#   'actual',
#   'known',
#   'page',
#   'numbers',
#   'contained',
#   'Kindle',
#   'version',
#   'would',
#   'purchased',
#   'would',
#   'purchased',
#   'used',
#   'hard',
#   'copy'],
#  ['Brain',
#   'based',
#   'Learning',
#   'text',
#   'book',
#   'ordered',
#   'classes',
#   'teacher',
#   'book',
#   'easy',
#   'read',
#   'really',
#   'enjoying',
#   'presents',
#   'info',
#   'end',
#   'section',
#   'recaptures',
#   'essence',
#   'reading',
#   'would',
#   'suggest',
#   'teaching',
#   'learning',
#   'much',
#   'buying',
#   'text',
#   'books',
#   'Amazon',
#   'much',
#   'cheaper',
#   'sometimes',
#   'get',
#   'free',
#   'far',
#   'book',
#   'could',
#   'find',
#   'Amazon'],
#  ['Pop',
#   'psychology',
#   'worst',
#   'find',
#   'hard',
#   'believe',
#   'people',
#   'fall',
#   'writes',
#   'much',
#   'stuff',
#   'pulls',
#   'supposedly',
#   'based',
#   'brain',
#   'unfortunate',
#   'enough',
#   'take',
#   'class',
#   'requires',
#   'read',
#   'jumps',
#   'conclusions',
#   'little',
#   'evidence',
#   'back',
#   'Plus',
#   'neither',
#   'teacher',
#   'found',
#   'something',
#   'write',
#   'sound',
#   'like',
#   'Plus',
#   'writing',
#   'seems',
#   'written',
#   'let',
#   'say',
#   'young',
#   'simplistic',
#   'always',
#   'bad',
#   'case',
#   'read',
#   'Analyze',
#   'statements',
#   'look',
#   'actual',
#   'scientific',
#   'proof',
#   'find',
#   'either',
#   'book',
#   'Total',
#   'fluff'],
#  ['Science',
#   'average',
#   'breathe',
#   'one',
#   'nostril',
#   'three',
#   'hours',
#   'tissue',
#   'becomes',
#   'slightly',
#   'engorged',
#   'switch',
#   'nostril',
#   'breathe',
#   'affects',
#   'brain',
#   'hemisphere',
#   'female',
#   'brain',
#   'processes',
#   'language',
#   'feeling',
#   'time',
#   'far',
#   'efficiently',
#   'male',
#   'brain',
#   'two',
#   'quotes',
#   'tell',
#   'need',
#   'know',
#   'quality',
#   'science',
#   'contained',
#   'teach',
#   'teachers'],
#  ...]

# %%
countvectorizer = CountVectorizer()
countvectorizer.fit([negs_s,pos_s])
# Out:
# CountVectorizer(analyzer='word', binary=False, decode_error='strict',
#         dtype=<class 'numpy.int64'>, encoding='utf-8', input='content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(1, 1), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern='(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
doc_vec = countvectorizer.transform([negs_s,pos_s])

# %%
df = pd.DataFrame(doc_vec.toarray().transpose(), index = countvectorizer.get_feature_names())

# %%
df.sort_values(1, ascending=False)
# Out:
#                      0     1
# book              5131  5723
# great             1245  4347
# one               3489  3715
# good              2258  3216
# like              3058  2717
# read              1861  2665
# love               597  2092
# would             3084  1991
# movie             2251  1877
# best               563  1747
# really            1571  1666
# get               2103  1647
# cd                 793  1582
# time              1746  1522
# well               913  1493
# first             1368  1403
# story              952  1287
# album              588  1228
# much              1446  1224
# also               800  1140
# even              1742  1094
# could             1591  1085
# little             815  1040
# think              953  1040
# music              589  1036
# recommend          545   983
# many               839   963
# still              698   953
# new                844   927
# way                940   917
# ...                ...   ...
# resuming             1     0
# resurecting          1     0
# restatement          1     0
# restate              1     0
# restarts             1     0
# cinelli              1     0
# homophobia           1     0
# homophobe            1     0
# homogenized          1     0
# homoerotic           1     0
# responder            1     0
# homocidal            1     0
# responds             1     0
# respondsibilty       1     0
# respondsible         1     0
# responible           1     0
# homo                 2     0
# responsei            1     0
# hommies              1     0
# responsibilities     1     0
# homily               1     0
# homey                1     0
# ressistance          1     0
# ressler              1     0
# homewrecker          1     0
# bangs                2     0
# restaraunt           1     0
# cindy                2     0
# homeviewer           1     0
# única                1     0
#
# [40981 rows x 2 columns]

# %%
from sklearn.naive_bayes import GaussianNB

# %%
model = GaussianNB()

# %%
model.fit(countvectorizer.transform(data[:20000]).toarray(), labels)
